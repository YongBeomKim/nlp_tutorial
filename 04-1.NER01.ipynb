# %% [markdown]
# # **NER 사전 만들기**
# https://pypi.org/project/mdict-utils/
# 1. **MDX 사전파일을** 활용하여 객체에 구분하기
#
# ## **1 Sqlite3 to Pandas**
# MDX 사전파일을 Sqlite3 로 변경한 뒤, 작업에 유용한 형태로 전처리 하기

# %%
import sqlite3
import pandas as pd
# Create your connection.
conn = sqlite3.connect('backup/kordict.db')
resp = conn.execute("SELECT name FROM sqlite_master WHERE type='table';")
tableNames = [name[0]  for name in resp]
tableNames
# Out:
# ['meta', 'mdx']

# %%
# %%time
df = pd.read_sql_query("SELECT * FROM {}".format(tableNames[1]), conn)
df.head()
# Out:
# CPU times: user 1.18 s, sys: 140 ms, total: 1.32 s
# Wall time: 1.32 s
#   entry                                         paraphrase
# 0     ᄛ  <font color=crimson size=+2><b>ᄛ</b></font><br...
# 1     ᄻ  <font color=crimson size=+2><b>ᄻ</b></font><br...
# 2     ᆐ  <font color=crimson size=+2><b>ᆐ</b></font><br...
# 3     ㄱ  <font color=crimson size=+2><b>ㄱ</b></font><br...
# 4     ㄱ  <font color=crimson size=+2><b>ㄱ</b></font><br...

# %% [markdown]
# ## **2 사전파일 살펴보기**
# **paraphrase** 내용을 **사용자가 필요한 형태로** 변경하기
# ```html
# <font color=crimson size=+2>
#     <b>ㄹ라</b>
# </font>
# <br>
# <br>
# <font color="#00008b">
#     <b>-ㄹ라03</b>
# </font>
# <br>
# <font color="#549606">
#     <b>「어미」</b>
# </font>
# <br>『방언』<br>‘-려04’의 방언(경상).\r\n
# ```

# %%
# 색인정보 : 51만개의 단어사전 데이터
itemIndex = df.entry.values.tolist()
itemData  = df.paraphrase.values.tolist()
len(itemIndex), itemIndex[:10]
# Out:
# (516490, ['ᄛ', 'ᄻ', 'ᆐ', 'ㄱ', 'ㄱ', 'ㄱㄴㄷ순', 'ㄱㄴㄷ차례', 'ㄱㄴ순', 'ㄱㄴ차례', 'ㄱ자'])

# %%
data = itemData[0]
data = data.lower()  # html Tag 전처리
print(data)

# 간단하게 처리한 뒤 유사내용 묶기
from lxml.html import fromstring
fromstring(data).xpath('//text()')
# Out:
# <font color=crimson size=+2><b>ᄛ</b></font><br><br><font color="#00008b"><b>ᄛ</b></font>『옛말』<br>『언어』<br>한글 옛 자모의 하나. 반설경음이라 이르며, 혀끝이 윗잇몸을 가볍게 두들겨 내는 유음으로 짐작된다.
# ['ᄛ',
#  'ᄛ',
#  '『옛말』',
#  '『언어』',
#  '한글 옛 자모의 하나. 반설경음이라 이르며, 혀끝이 윗잇몸을 가볍게 두들겨 내는 유음으로 짐작된다.\r\n']

# %% [markdown]
# ## **3 Regex를 활용하여 구분하기**
# 본문에 "\<br\>" 내용이 많아서 "//text()" 를 사용하면 컬럼갯수가 꼬여버린다
# regex, lxml 을 사용하면 좋겠지만 경우의 수가 많아서 모두 처리하지 않으면 안됨..

# %%
data = itemData[2945]
data = data.lower()  # html Tag 전처리
data
# Out:
# '<font color=crimson size=+2><b>가변표지</b></font><br><br><font color="#00008b"><b>가변^표지(可變標識)</b></font>『교통』<br>교통에 대한 규제나 경고, 안내 따위의 내용을 시간별로 또는 원격 조정 신호에 따라 자동적으로 변경하는 표지.\r\n'

# %%
import re
re.findall(r'<font color=crimson (.*?)</font>', data, re.DOTALL)
# Out:
# [' size=+2><b>가변표지</b>']

# %%
import re
# html 태그내용 제거하는 함수
def remove_html_tags(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %%
remove_html_tags(data)
# Out:
# re.compile('<.*?>')
# '가변표지가변^표지(可變標識)『교통』교통에 대한 규제나 경고, 안내 따위의 내용을 시간별로 또는 원격 조정 신호에 따라 자동적으로 변경하는 표지.\r\n'

# %%
from bs4 import BeautifulSoup
dom = BeautifulSoup(data, "lxml")
bs_dom = dom.find_all('font')
bs_txt = [str(_.get_text()) for _ in bs_dom]
bs_txt
# Out:
# ['가변표지', '가변^표지(可變標識)']

# %%
bs_result = list(map(lambda x : str(x),  bs_dom))
bs_result[0]
# Out:
# '<font color="crimson" size="+2"><b>가변표지</b></font>'

# %%
bs_result = list(map(lambda x : str(x),  bs_dom))
bs_result[1]
# Out:
# '<font color="#00008b"><b>가변^표지(可變標識)</b></font>'

# %%
re.sub('color="#00008b">', "", data)
# Out:
# '<font color=crimson size=+2><b>가변표지</b></font><br><br><font <b>가변^표지(可變標識)</b></font>『교통』<br>교통에 대한 규제나 경고, 안내 따위의 내용을 시간별로 또는 원격 조정 신호에 따라 자동적으로 변경하는 표지.\r\n'

# %%
re.sub("<font", "", data)
# Out:
# ' color=crimson size=+2><b>가변표지</b></font><br><br> color="#00008b"><b>가변^표지(可變標識)</b></font>『교통』<br>교통에 대한 규제나 경고, 안내 따위의 내용을 시간별로 또는 원격 조정 신호에 따라 자동적으로 변경하는 표지.\r\n'

# %%
"".join(dom.find_all('font'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-57833c150e7c> in <module>
# ----> 1 "".join(dom.find_all('font'))
#
# TypeError: sequence item 0: expected str instance, Tag found

# %%
import re # 강결합으로 정치큰 부분 제거하기
re.sub('<br><font color=.*</font>', "",data)
# Out:
# '<font color=crimson size=+2><b>ᄛ</b></font><br>『옛말』<br>『언어』<br>한글 옛 자모의 하나. 반설경음이라 이르며, 혀끝이 윗잇몸을 가볍게 두들겨 내는 유음으로 짐작된다.\r\n'

# %%
_ = re.sub('<font .*</font><br>', "",data).split("<br>")
_[0], _[1].replace("\r\n", "")
# Out:
# ('', '<font color="#00008b"><b>ᄛ</b></font>『옛말』')

# %%
data
# Out:
# '<font color=crimson size=+2><b>ᄛ</b></font><br><br><font color="#00008b"><b>ᄛ</b></font>『옛말』<br>『언어』<br>한글 옛 자모의 하나. 반설경음이라 이르며, 혀끝이 윗잇몸을 가볍게 두들겨 내는 유음으로 짐작된다.\r\n'

# %%
re.findall(r"", )

# %% [markdown]
# ## **3 함수의 적용**
# 작업용 함수를 작성한 뒤 응용하기

# %%
from lxml.html import fromstring
def exportTxt(data):
    yield fromstring(data).xpath("//text()")

# result = list(map(lambda x: next(exportTxt(x)), itemData[:200000]))
# result = list(map(lambda x: next(exportTxt(x)), itemData[200000:400000]))
result = list(map(lambda x: next(exportTxt(x)), itemData[400000:]))

import pickle
# Store data (serialize)
with open('data3.pk', 'w') as handle:
    pickle.dump(result, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## **4 Pickle 내용 합치기**
# 작업용 함수를 작성한 뒤 응용하기

# %%
from glob import glob
pklist = sorted(glob('data?.pk'))

# Load data (deserialize)
import pickle
result = []
for _ in pklist:
    with open(_, 'rb') as handle:
        result.extend(pickle.load(handle))

# %%
with open('data.pk', 'wb') as handle:
    pickle.dump(result, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## **5 사전자료 전처리 작업**
# 작업용 함수를 작성한 뒤 응용하기

# %%
with open('data.pk', 'rb') as handle:
    mdkList = pickle.load(handle)

mdkList =[ list(map(lambda x:str(x), _)) for _ in mdkList]
len(mdkList)

# %%
mdkList[3][-2]
# Out:
# '『언어』'

# %%
# tag 내용만 추출하기
tags = [_[-2]  for _ in mdkList]
len(set(tags))
# Out:
# 121348

# %%
list(set(tags))
# Out:
# ['어떤 한 곳이나 일에 관심을 집중하여 기울이다.',
#  '갖가지 약. ',
#  '‘부인01(夫人)’의 옛말. ',
#  '다채롭다. 세미하다03. ',
#  '빗줄기나 물줄기 따위가 굵고 세찬 것을 비유적으로 이르는 말.',
#  '조금 휘어져 뒤로 자빠질 듯 비스듬하다.',
#  '부녀자들로 구성된 모임. 흔히 마을ㆍ동(洞)ㆍ아파트 따위의 인근 지역 사회라든가 종교 단체 따위에서, 부녀자들이 모임을 구성하여 아이들의 교육이나 일상생활 문제 따위에 공동으로 대처한다. ',
#  '‘좁쌀’의 옛말. ',
#  '무인으로서의 운수. ',
#  '임금이 나라 안을 두루 살피며 돌아다니다. ≒순공하다01ㆍ순행하다02.',
#  '‘출사하다01(出仕―)’의 옛말. ',
#  '적의 사격이나 관측으로부터 아군을 보호하기 위하여 땅을 파서 만든 구덩이. ≒벙커',
#  '복잡하게 그려 놓은 그림에 숨겨진 물건을 찾도록 한 놀이. ',
#  '열렬히 사랑하다.',
#  '특수한 칠감을 발라 어두운 곳에서 빛을 내게 하는 색종이. ≒발광색지. ',
#  '앞으로의 일이 어떻게 될 것인가가 미리 정해지다.',
#  ' =은퇴하다.',
#  '앞으로 닥쳐올 일이 미리 생각되고 기다려지다.',
#  '빌려 주다. ',
#  '물고기가 한창 알을 낳는 때. ',
#  '자연치료 수단을 개발하여 사람의 체력 단련이나 질병의 예방ㆍ치료에 이용하는 것을 연구하는 학문. 임상 의학의 한 분야이다.',
#  '진귀한 책. ≒진본01(珍本)ㆍ진적01(珍籍).',
#  '촘촘하게 늘어서 있다. ',
#  '‘물건’의 뜻을 더하는 접미사.',
#  '무농성잇과 살파의 하나. 무성 세대 개체의 길이는 5~12mm, 유성 세대 개체의 길이는 3~6mm이며 항아리 모양이다. 따뜻한 바다에 살면서 해초와 작은 갑각류를 먹는데 바닷물고기의 좋은 먹이가 된다.',
#  '【…을】공공의 물건을 사사로이 쓰다.',
#  '기쁨이나 분노 따위의 감정이 격렬히 일어나게 되다.',
#  '마음씨가 고우면 옷 앞섶이 아문다',
#  '헤아릴 수 없다.',
#  '얼음이 깔려 있는 길. ',
#  '사람을 자기 마음대로 움직이다. ',
#  '어떤 일을 좋은 방향으로 이끌어 가려는. 또는 그런 것.',
#  '【…을】규범으로 되게 하다.',
#  '양귀비과의 두해살이풀. 줄기는 높이가 5~10cm로 양귀비와 비슷한데 온몸에 거친 털이 많다. 잎은 뿌리에서 뭉쳐나고 달걀꼴 타원형으로 1~3회 깃 모양으로 깊이 갈라진다. 한 개 또는 두 개의 꽃줄기 끝에 노란색 꽃이 하나씩 달리고 열매는 삭과(蒴果)를 맺는다. 백두산에 분포한다. (Papaver radicatum var. pseudoradi-catum) ',
#  '갑자기 눈물이 글썽해지는 모양. ‘빙02「4」’보다 거센 느낌을 준다. ',
#  '탐이 나서 눈독 들여 겨누어 보다. ',
#  '¶ 안팎이 다른 량면분자.',
#  '걸어가다가도 말만 보면 타고 가자고 한다',
#  '원칙이 없다.',
#  ' =분수05(分數). ',
#  '【…을】【-고】말을 낮은 목소리로 계속하다. ‘주절주절하다01「1」’보다 센 느낌을 준다.',
#  '각론에 대한 과학. 또는 각론에 대한 과목. ',
#  '엄한 명령 아래. ',
#  '『북한어』법도에 맞고 바른 규모. ',
#  '무당이 점을 치거나 굿을 할 때에 쓰는 특별한 말. ',
#  '자리에서 일어나다. 또는 자리에서 물러나다.',
#  '큰춤(을) 보다',
#  '어떤 사물의 효과나 작용이 다른 것에 미치는 힘. 또는 그 크기나 정도. ',
#  '어떤 일에 경험이 없어 솜씨가 서툰 사람. ',
#  '육장(을) 내다',
#  '톱니바퀴의 톱니를 깎는 공구의 하나. 기어 종삭반(縱削盤)에 설치하여 직선, 경사, 외면, 이중 경사, 계단 기어 따위를 가공할 수 있다.',
#  '검사, 시험, 심의 따위에서 해당 기준이나 조건에 맞아 인정되거나 합격하다.',
#  '차와 차 사이의 거리. 달리고 있는 차가 자기 차로의 앞의 차와 지켜야 하는 간격을 이른다. ',
#  '가장 긴 기간.',
#  '물방울 따위가 자꾸 떨어지는 소리가 나다.',
#  '‘부채01’의 옛말. ',
#  ' =체온계.',
#  '세찬 바람과 함께 휘몰아치는 비. ',
#  '‘비소하다01(卑小―)’의 옛말. ',
#  '물가 따위가 떨어지는 기세.',
#  '‘아버지’의 옛말. 조사 ‘\ueea4, 의’ 앞에서는 ‘ㅣ’가 탈락하여 ‘압’으로 나타난다. ',
#  '전체를 반씩 둘로 나눈 것의 뒤쪽 반.',
#  '더할 수 없이 순결하다.',
#  '생각보다 태도나 행동이 영악하다. ',
#  '두견과의 하나. 뻐꾸기와 비슷하나 조금 작고 편 날개의 길이는 18~21cm, 꽁지의 길이는 12~17cm이며, 푸른빛을 띤 회색에 배 부분은 누런 갈색이고 검은 무늬가 있다. 우는 소리가 죽통(竹筒)을 치는 소리와 비슷하고 봄에 다른 새의 둥지에 알을 낳는다. 곤충을 잡아먹고, 한국ㆍ시베리아ㆍ중국 등지에서 번식하며 인도ㆍ오스트레일리아 등지에서 겨울을 보내는 철새이다. ≒통조(筒鳥). (Cuculus saturatus)',
#  '두 직선이 만났을 때 서로 이웃하지 않는 두 각. ≒상응각',
#  '‘뚫어지다’의 옛말. ',
#  '남보다 먼저 어떤 일을 시작하거나 길을 떠나다.',
#  '자유롭게 이리저리 슬슬 거닐며 돌아다니다.',
#  '한 지점에서 길이 네 방향으로 갈라져 나간 곳. ≒사가05(四街)ㆍ사거리01ㆍ십자로. ',
#  '기술보다 몸의 단련된 힘으로 밀어붙여 하는 경기. ',
#  '¶ 정기 국회가 개회하기까지는 일주일 남았다.∥시 의회는 임시회를 개회했다.',
#  '훔쳐 빨다. ',
#  ' =온데간데없이.',
#  '어느 곳에서 원하는 곳에 이르도록 전선 따위를 늘리다. ',
#  '【…에게 …을】자세히 설명하다.',
#  '임금이나 국가에 대하여 진정으로 우러나오는 정성스러운 마음. ',
#  '굽이진 길. ',
#  '물에 흠뻑 젖은 상태. 또는 그런 사람을 놀림조로 이르는 말.',
#  '수준 따위가 높은 부류.',
#  '¶ 사퇴서를 수리하다.',
#  '치안감(계급장)',
#  '전쟁이나 재난 따위로 사회가 크게 혼란해지는 일. ',
#  '『북한어』몸을 뒤집으며 재주를 넘다. ',
#  '‘빨래하다’의 옛말. ',
#  '태어나서 자란 원래의 터전. ',
#  '방망이로 갑자기 세게 때리는 것을 비유적으로 이르는 말. ',
#  '‘…인 체하다’, ‘…인 것처럼 뽐내다’의 뜻을 더하는 접미사. ',
#  '장인과 사위를 아울러 이르는 말.',
#  ' 어떤 글을 대조하여 볼 때 맞다는 뜻으로, 글의 첫머리에 ‘△’ 표를 하다.',
#  '가리02「1」 ',
#  '들어가다가 돌아서 도로 나가다. ',
#  '조정에 가득하다.',
#  '일정한 책임이나 일을 부담하여 맡게 하다.',
#  '인들. ',
#  '‘뒤집어엎다’의 북한어. ',
#  '일정한 분야에서 주로 사용하는 말. ‘쓰는 말’로 순화. ',
#  '¶ 나지막한 목소리/명수는 그의 눈을 뚫어져라 바라보며 나지막하게 말을 이었다.≪한수산, 부초≫',
#  '【…을】싸워서 공격하다. 또는 격렬하게 싸우다.',
#  '어떤 사물을 연구하는 데 드는 비용. ',
#  '두 손을 엇갈리게 하여 주먹을 쥐고 열 손가락을 밖으로 드러내 보이게 하는 결인(結印). ≒외박권ㆍ외박인.',
#  '나흘이나 닷새가량. ≒너더댓새.',
#  '목이 잠겨 소리가 제대로 나지 아니하다.',
#  '일반적으로 매장된 광물 가운데 공업 원료나 건설 재료 따위로 이용할 수 있는 것.',
#  '아름답지 못하고 추잡하다.',
#  '미꾸릿과의 민물고기. 몸의 길이는 10~13cm이며, 연한 노란색 바탕에 어두운 갈색 가로줄이 범 무늬를 이룬다. 낙동강 상류의 여울에 사는데 우리나라 특산종이다. (Niwaella multifasciata)',
#  '동서로 이어진 강의 남쪽 지역. ',
#  '몸의 모양이나 태도 따위를 바꾸는 기술. ',
#  ' =눈앞. ',
#  '얼굴이 여위고 핏기가 없다.',
#  '노란빛을 띤 하얀빛.',
#  '구역을 갈라 정하는 선. ',
#  '삼보(三寶)에 돌아가 몸과 마음을 불도에 의지하다.',
#  '【…에서】【…으로】',
#  '【…을】 말없이 남의 말의 참뜻을 깨닫거나 기억해 두다.',
#  '¶ 바드름히 내민 덧니.',
#  '‘감수성02(感受性)’의 북한어. ',
#  ' =정신계. ',
#  '‘짧은아가미미갑갯지렁이’의 북한어.',
#  '일의 진행이 나쁜 방향으로 되어 가는 상태.',
#  '바닥에 기다랗게 눕다. 또는 누운 것처럼 놓이다. ',
#  ' =정계04(政界). ',
#  '주정뱅이는 상감님 망건 살 돈도 술 사 먹는다',
#  '조금 거만스럽게 잘난 체하며 버릇없이 자꾸 굴다. ‘가드락가드락하다’보다 센 느낌을 준다.',
#  '물의 근원이나 원천. ',
#  '흰 겨자. ',
#  '하는 짓이 시원스럽게.',
#  '갈매깃과의 새. 재갈매기와 비슷하나 등이 어두운 잿빛이고 부리 아랫면에 붉은 점이 있다. (Larus schistisagus)',
#  '김치를 잘게 썰어서 두부, 기름, 양념 따위와 함께 섞어 만든 솟거리. ',
#  '패독산에 승검초',
#  '금속 따위를 재결정 온도보다 낮은 온도로 처리함.',
#  '가까이 있는 사람을 친근하게 부를 때 쓰는 말. 하게할 자리에 쓰인다.',
#  '본디의 것과 똑같이 본떠 만든 물품. ',
#  '차례나 횟수를 나타내는 말. ',
#  '목석도 땀 날 때 있다',
#  '‘저술’이나 ‘저작’의 뜻을 나타내는 말. ',
#  '빚 준 상전이요 빚 쓴 종이라',
#  '『북한어』남의 비위를 맞추려고 모양이나 행동을 꾸며 가면서 용렬하게 굴다. ',
#  '개가하여 온 아내가 데리고 들어온 딸. 또는 남편의 전처가 낳은 딸. ≒의녀01(義女).',
#  '【…을】물건이나 돈 따위를 자주 조금씩 쓰거나 여러 번 나누어 주다.',
#  '【…을】 범죄로 보다. 또는 범죄처럼 여기다.',
#  ' =해죽01. ',
#  '재정의 기초를 다지기 위하여 지출을 줄이다.',
#  '논밭이나 들 따위가 묵어서 거칠게 되다.',
#  '‘가을철’의 옛말. ',
#  '각각의 골목. 또는 모든 골목. ',
#  '목탁귀가 밝아야 한다',
#  '밑에 댄 옷단. ',
#  '하게할 자리에 쓰여, 기꺼이 하겠다는 뜻을 나타내는 종결 어미.',
#  '¶ 훌렁하고 편안한 옷/바짓가랑이가 훌렁하다.',
#  '저고리나 두루마기의 안으로 들어간 섶.',
#  '『음악』음악, 연극 따위에서 단락, 과장, 마당을 이르는 말. ',
#  '【…을】 골라서 쓰다.',
#  '연결되어 있는 회로의 유효 전력을 시간에 따라 적산하여 측정하고 기록하는 전기 계기의 하나. 단위는 kwh. ≒와트시미터ㆍ적산 전력계ㆍ전기 계량기ㆍ전기미터ㆍ전기 에너지 미터. ',
#  '집이나 마을 뒤에 있는 들. ≒뒷벌.',
#  '말이나 행동이 매우 능글맞다. ',
#  '황산마그네슘이 4~5% 들어 있는 시멘트. 건축물의 안벽, 마루, 천장 따위를 미장하거나 마른 미장 판, 막이 판 따위를 만드는 데 쓴다.',
#  '저만큼 된 때. ',
#  '시간이 오래 걸리거나 같은 상태가 오래 계속되어 따분하고 싫증이 나다. ',
#  '얼어 죽은 사람. ',
#  '완전한 형체. ',
#  '정류된 전원에 포함되어 있는 맥동 성분을 제거하기 위한 장치.',
#  '작게. ',
#  '재간이 없는 사람을 놀림조로 이르는 말. ',
#  '【…을】조상의 묘를 깨끗이 하고 돌보다.',
#  '‘굴리다[1]’의 옛말. ',
#  '¶ 임원 회의에서 상후하박한 임금 체계를 개선하는 방안을 마련하기로 하였다.',
#  '흥분한 분위기. ',
#  '【…을】 많이 만들어 내다.',
#  '자두나무의 열매. 살구보다 조금 크고 껍질 표면은 털이 없이 매끈하며 맛은 시큼하며 달콤하다. ≒자리13(紫李). ',
#  '힘차게 뜀을 뛰다. ',
#  '끊어지지 않고 계속되다. ',
#  '밥 따위가 알알이 흩어지게 풀기가 적다.',
#  '귀천궁달이 수레바퀴다',
#  '사랑으로 쓰는 집채. ',
#  '태극 모양을 그린 둥근 부채. ≒태극부채.',
#  '어떤 결과나 효과가 지체 없이 곧바로 나타나는 일.',
#  '원통 겉면이 매끈한 다짐 기계. 흙ㆍ모래ㆍ자갈 따위를 다질 때 쓰며, 특히 아스팔트 도로포장의 완성 작업에 많이 쓴다.',
#  '솜털로 된 깃. ',
#  '【…을】 =내뜨리다 ',
#  '‘달까닥달까닥하다’의 준말.',
#  '¶ 마루에서 뻐꾸기시계가 ‘뻐꾹, 뻐꾹’ 두 번을 운다.',
#  '염려가 되어 마음을 놓지 못하고 조바심하며 자다. ',
#  '충직하고 성실하다.',
#  '【…을】참고 억제하다.',
#  '오릿과의 새. 수컷은 머리와 목이 광택이 있는 녹색이고 흰 띠가 둘려 있으며 부리는 갈색, 꽁지는 흰색이나 암컷은 전체적으로 갈색을 띠며 어두운 갈색의 무늬가 있다. 농경지 등지에서 사는데 4월 하순에서 7월에 걸쳐 6~12개의 알을 낳는다. 남쪽에서 겨울을 보내며 우리나라에는 흔한 겨울새로 유럽, 아시아, 아프리카 등지의 북반구에 분포한다. ≒물오리ㆍ야목(野鶩)ㆍ야부02(野鳧)ㆍ야압(野鴨)ㆍ침부02(沈鳧). (Anas platyrhynchos) ',
#  '털이나 풀 따위의 빛깔이 노르스름하다.',
#  '특수한 가스를 냉매로 쓰는 압축식 냉동기. 수소나 헬륨 따위의 특수 가스를 압축한 뒤 팽창시키면서 낮은 온도를 얻으며, 냉매로 쓰는 가스보다 높은 액화점을 가지는 공기, 산소, 질소 따위의 기체를 액화하는 데 쓴다.',
#  '¶ 로간부와 젊은 간부를 적절히 배합하여 간부 대렬을 꾸린다.≪선대≫',
#  ' =평상복.',
#  '오늘이나 내일 사이. ‘곧01’, ‘오늘 내일 사이’로 순화. ≒금명(今明). ',
#  '미미하고 약하다. ≒쇄미하다01[Ⅱ]. ',
#  '【…을】 자금이나 물자 따위를 대어 주다.',
#  '【…을】존경하여 믿다.',
#  '¶ 날씨가 얼마나 더운지 아이들 손에 들려 있는 아이스케이크가 녹아 흐르고 있었다.',
#  '세게 쏘다. ',
#  '【…을】 상태가 나아가지 못하고 한 자리에 머무르다.',
#  '¶ 군수는 꺽정의 계집에게 봉욕하고 꼭뒤까지 났던 화가 꺽정의 누이를 문초 받는 중에 많이 풀리었으나….≪홍명희, 임꺽정≫',
#  ' =틈01[Ⅰ].',
#  '그릇이나 냄비 따위의 손잡이. ',
#  '법률과 명령을 아울러 이르는 말. ≒영06(令)',
#  '때가 섞인 물기가 마른 흔적. ',
#  '뭍에서 큰 배에 오르내리기 위하여 걸쳐 놓는 사다리. ',
#  ' =말꼴. ',
#  ' =동맹국(同盟國). ',
#  '음력으로 쇠는 설. 음력 정월 초하루를 새해 명절로 이르는 말이다.',
#  ' =제삿밥. ',
#  '어떤 일을 본격적으로 하기에 앞서 시험 삼아 해 보는 일. ',
#  '알루미늄 전해질의 껍데기를 깨는 압축 공기식 기계. 압축 공기로 움직이는 망치가 아래위로 왕복 운동을 하면서 전해질의 껍데기에 구멍을 뚫는다.',
#  '말이 미치면 소도 미친다',
#  '‘책상다리「1」’의 북한어. ',
#  '책임이나 의무를 맡다. ',
#  '사람이 들어 살거나, 일을 하거나, 물건을 넣어 두기 위하여 지은 집을 통틀어 이르는 말. ',
#  '‘나박김치「1」’의 옛말. ',
#  '운동 경기 따위에서, 선수들의 사기를 북돋워 주기 위하여 여럿이 부르는 노래. ',
#  '『역사』【…에/에게 …을】고을 원이 세금을 거두어서 나라에 바치다.',
#  '‘-사오이다’의 준말. ≒-소다03.',
#  '‘광01’의 원말. ',
#  '나쁜 생각이나 버릇을 털어 없애다.',
#  '예전에, 볼기를 치는 데 쓰던 채찍. ',
#  '‘-는다고 하여야’가 줄어든 말.',
#  '남편의 할아버지. ≒시조부. ',
#  '대답하여 말하다.',
#  '잔손이 많이 들어 정밀하게 만들어지다.',
#  '우묵하게 들어가 물이 괸 곳. ',
#  '【…을】 =쭈크러뜨리다. ',
#  '【(…을)】현실로 되다. 또는 현실에 맞게 만들다.',
#  '‘돌이키다’의 옛말. ',
#  '돈이 많이 들어오는 것을 비유적으로 이르는 말.',
#  ' =평상시. ',
#  '한동안 잠잠하던 일이 다시 문제가 되어 시끄럽게 되다.',
#  '‘맛깔스레’의 북한어.',
#  '‘화물 열차’를 줄여 이르는 말.',
#  '배를 같이 타다. ≒동선하다.',
#  '‘위연륜(僞年輪)’의 북한어.',
#  '아는 체를 하거나 관심 있게 보다. ',
#  '끝까지 다.',
#  '크게 느끼어 마음이 움직이다.',
#  '정체를 알 수 없는 수상한 배. ≒괴선01.',
#  '임금의 자리. ≒보위02(寶位)ㆍ보조05(寶祚)ㆍ어좌02(御座). ',
#  '잘록 들어간, 허리의 뒷부분. ≒세요01(細腰)',
#  '적의 성, 요새, 진지 따위가 공격을 받아 무너지다.',
#  '몽유병이 있는 사람. ',
#  '어리석고 정신이 흐릿하여, 일을 제대로 판단하고 처리하는 능력이 없다.',
#  '「2」짓궂게 조르며 못살게 굴다.',
#  '미쁘게. ',
#  '밝고 산뜻한 붉은색. ',
#  '여러 사람에게 알리기 위하여 내붙이거나 내걸어 두루 보게 한 물건이나 글. ',
#  '신선의 풍악.',
#  '학비를 스스로 벌어서 고생하며 공부하는 학생. ',
#  ' =독그릇. ',
#  '활의 한오금과 삼사미의 사이. ',
#  ' =농사철. ',
#  '네 개의 탄소 원자를 갖는 결합된 메탄계 탄화수소. 상온에서는 타기 쉬운 무색무취의 기체이며, 액화하기 쉽다. 천연가스나 석유 분해 가스에 들어 있으며, 노말 부탄과 이소부탄의 두 가지 이성질체가 있다. 연료나 석유 화학 원료 따위로 쓴다. 화학식은 C4H10. ≒부탄가스',
#  '‘솝뜨다’의 옛말. ',
#  '‘가랫날’의 옛말. ',
#  '천의 앞뒤 면에 같은 형태의 본을 수놓는 수예 형식. ≒량면수예.',
#  '조선 철종 12년(1861)에 김정호가 제작한 우리나라의 대축척 지도. 순조 34년(1834)에 김정호 자신이 제작한 ‘청구선표도’를 27년 후에 수정ㆍ증보한 것으로, 27년간 전국을 직접 답사하고 실측하여 만들었다. 22첩. ≒동여도.',
#  '가마를 메는 사람들이 쉬기 위하여 가마를 세워 놓을 때, 양옆에서 가마채 밑을 받쳐 들어 주는 장대.',
#  '바람직하지 못하거나 잘되지 아니할 것을 억지로 하는 일. ',
#  '쇠약해진 심장의 기능을 회복시키는 약. 디기탈리스, 디기톡신, 캠퍼, 아드레날린 따위가 있다.',
#  '【…을】일정한 권한을 가지고 통제하거나 지배하다.',
#  '구슬 따위의 울리는 소리가 맑고 아름답다.',
#  '예전에, 행랑에서 살던 하인을 낮잡아 이르던 말. ',
#  '대한 칠 년 비 바라듯',
#  '『법률』일정한 법률 사실이나 법률관계를 공증하기 위하여 행정 관서나 공공 기관 따위에 비치한 법정의 공부에 기재하도록 하는 제도.',
#  '【…을】무용이나 연극 따위를 일반에게 공개하기 전에 시험적으로 상연하다.',
#  ' =삼동네. ',
#  '‘-려고 하여야’가 줄어든 말.',
#  '겨울철에 주로 차고 누진 곳에 삐죽삐죽 올라와 기둥 모양으로 된 서릿발.',
#  '¶ 한 번 형벌을 받은 죄인을 번복하여 감죄하지 못한다.',
#  '일러져 말해지다.',
#  '『컴퓨터』【…을】하드웨어나 소프트웨어의 성능을 기존 제품보다 뛰어난 새것으로 변경하다.',
#  '【…에/에게 -고】잔소리를 자꾸 늘어놓다.',
#  '안에 솜을 두어 두껍게 만든 버선. ≒면말(綿襪). ',
#  '‘적시다01’의 옛말. ',
#  '튼튼하게 뿌리를 내리지 못하고 자라다. ',
#  '‘또한’의 옛말. ',
#  ' =촌사람.',
#  '의사의 진료를 돕고 환자를 돌보는 사람. 법으로 그 자격을 정하고 있다. ',
#  '¶ 새빨간 운동 샤쯔를 입고 채양이 긴 골프 모자에다 커다란 푸른색의 채양안경을 끼였다.≪선대≫',
#  '【…을】 구차한 말로 자꾸 지껄이다.',
#  '어떤 기관이 관할하는 구역의 안.',
#  '맹물에 조약돌을 삶아 먹더라도 제멋에 산다',
#  '그 집안의 본디 식구. ',
#  '¶ 매개 당들은 자기 나라 혁명과 건설에 대한 옳바른 지도리론을 가져야 혁명과 건설을 곧바른 승리의 한 길로 이끌어 나갈 수 있다.≪선대≫',
#  '상대편의 말에 찬성하는 뜻을 나타낼 때 쓰는 말. ',
#  '어떤 사람이나 단체를 대신하여 의견이나 태도를 표하는 일을 맡은 사람. ≒대변자. ',
#  '‘송송’의 옛말. ',
#  '긴 줄에 잇따라 매어 달린 여러 개의 등. ',
#  '「1」ㆍ직공03(職貢)ㆍ폐공01(幣貢). ',
#  '임시로 남의 집에 몸을 의지하고 지내다. ≒기주하다04. ',
#  ' =이내01.',
#  '【…을】 가볍게 주무르듯이 자꾸 만지다. ≒만지작대다.',
#  '우뢰처럼 만났다가 번개처럼 헤여진다',
#  '지략이나 행동 따위가 비길 데 없이 뛰어나고 재빠르다. ≒령활무비하다.',
#  ' =쇠-06.',
#  '영화다운. 또는 그런 것. ',
#  '악업의 맹화(猛火)',
#  '깊고 넓은 굴의 구멍. ≒동학04(洞壑).',
#  '날씨가 물체를 푹푹 쪄서 무르게 할 만큼 매우 더워지다.',
#  '공급하는 일을 맡아보는 곳. ',
#  '남사당패 놀이에서 부리는 재주의 하나. 앉았다 일어났다 하다가 뛰어서 돌아앉는다.',
#  '회사 따위에 찾아오다.',
#  '주의하지 않고 건성으로 듣는 귀. 또는 그런 귀의 능력.',
#  '‘똑01’의 옛말. ',
#  '비나 햇빛과 같은 것이 통하지 못하도록 우산이나 양산을 펴 들다. ',
#  ' =최상급.',
#  '연결 어미 ‘-고’와 조사 ‘는’이 결합한 ‘-고는’이 줄어든 말. ',
#  '¶ 바위산을 굴착하여 터널을 만드는 공사가 한창이다./최신 장비를 들여다가 수직갱을 굴착해 보리라는 소문이 퍼지자….≪최인호, 지구인≫',
#  '‘적요하다01’의 원말.',
#  '무쇠가 액체 상태로 녹은 것. ',
#  ' =무색옷.',
#  '‘수산업 협동조합’을 줄여 이르는 말.',
#  '「2」ㆍ실랑이하다.',
#  '그와 나 또는 저편과 이편을 아울러 이르는 말. ',
#  '과거에 합격한 사람의 발표를 취소하다.',
#  '시간상으로 있은 지 얼마 안 되어. ≒거미구에.',
#  '끊어졌던 행위나 상태를 다시 이어 나가다.',
#  '중국에서 나는 비단을 모방하여 짠 프랑스 비단. ',
#  '「2」ㆍ진성대.',
#  '어떠한 일 따위가 충격을 받을 만큼 매우 놀랍다. ‘충격적이다’로 순화. ',
#  '남의 비위를 맞추거나 환심을 사려고 더럽게 자꾸 아첨을 떨다. ≒얼렁대다01.',
#  '‘겹쓰다02「2」’의 피동사. ',
#  '¶ 사장의 눈이 깜작깜작할 때마다 사원들의 가슴은 뛰고 있었다.∥조 첨지는 눈을 깜작깜작하고 한 손으로 채수염을 쓰다듬으며….≪이기영, 고향≫',
#  '‘한나절’의 옛말. ',
#  '전문적으로 되다.',
#  '‘홀보드르르하다’의 준말.',
#  '농지의 소재지에 살고 있지 아니한 땅임자. 농지를 타인에게 임대해 주고 그 소득의 일부를 차지하는 형식으로 농지를 운영한다.',
#  '『북한어』외교 문제에서 공평한 관계를 가지지 아니하고 어느 한쪽으로 치우치는 정책.',
#  '보석을 사고파는 가게.',
#  '시험 문제를 내거나 시험 감독을 하며 그 성적을 채점하는 사람. ',
#  '‘싱크로나이즈드 스위밍’의 북한어.',
#  '여자가 다시 시집가서 살다. ≒후가하다.',
#  '판단이나 행동 따위가 사리에 어긋나지 아니하고 알맞게.',
#  '결정하는 권한이 있는 사람. ',
#  '『북한어』저녁밥을 짓거나 밥을 덥히기 위하여 때거나 지피는 불. ',
#  '구민법(舊民法)에서, 법률상 가독 상속에 의하여 피상속인의 지위를 승계하는 사람. 법정 가독 상속인, 독정(督定) 가독 상속인, 선정 가독 상속인의 세 가지가 있다.',
#  '잘게 썬 과일에 양주나 주스를 부어서 만든 음료.',
#  '((일부 명사 앞에 붙어))모체에 딸려 있음을 나타내는 말.',
#  '떠나는 사람을 기쁜 마음으로 보내는 뜻으로 하는 인사말.',
#  '자꾸 혀를 차며 크게 입맛을 다시는 소리. ',
#  '독청버섯과의 식용 버섯. 갓은 처음에 반구(半球) 모양이나 펴지면 넓적하게 되며, 빛깔도 밤색에서 갈색으로 바뀐다. 가을에 낙엽 활엽수의 그루터기 따위에 무리 지어 난다. ≒맛버섯. (Pholiota nameko) ',
#  '공부하기 위하여 따로 마련한 방. ≒서헌(書軒). ',
#  '구눙 놀다',
#  '차, 수레, 자전거 따위에서 짐을 싣는 밑판. ',
#  '규모가 큰 극장.',
#  '((일부 명사 앞에 붙어))‘기울어진’의 뜻을 더하는 접두사. ',
#  '‘느낌’의 뜻을 더하는 접미사. ',
#  '남보다 앞장서서 행동해서 몸소 다른 사람의 본보기가 되다.',
#  '고루 있는 대로.',
#  '남의 일에 끼어들어 이래라저래라 말을 하다.',
#  '풍치 보존과 학술의 참고 및 그 번식을 위하여 보호하는 나무.',
#  '동성아주머니 술도 싸야 사 먹지',
#  '풍치가 있고 조촐하다. ',
#  ' =관노비.',
#  '【…을】 보리나 수수 따위의 겉곡식을 대강 찧다. ',
#  '몹시 강하고 자극적인 냄새. ',
#  '흙이 엉기어 뭉쳐진 덩어리.',
#  '붉은 진흙. ',
#  '【…이】마음이 쓰여 속이 몹시 타다. ‘버글버글하다01[3]’보다 센 느낌을 준다.',
#  '나직한 소리로 조금 떠들썩하게 이야기하여 시끄럽다. ',
#  '사귀어 지내는 사이가 아주 가까운 맛. ',
#  '장사를 마치다.',
#  '『북한어』((‘-면’과 함께 쓰여))생각하거나 확신한 대로 결과가 나타나다. ',
#  '어떤 일을 많이 하여 아주 지겹도록 싫어지거나 귀찮다. ',
#  '이의 사기질과 상아질을 뚫는 기구.',
#  '건물의 모서리에 추녀가 없이 용마루까지 측면 벽이 삼각형으로 된 지붕. ≒게이블지붕.',
#  '진기하게 빼어나다.',
#  '기준이나 표준에 비하여 지나치게 많이 나가는 몸무게. ',
#  '문으로 들어가는 목의 첫머리.',
#  '『수학』=사각형. ',
#  '‘묻히다02’의 옛말. ',
#  '서양 음계의 넷째 음. 으뜸음보다 완전5도 아래의 음으로, 딸림음 다음가는 중요한 음이며 내림표 음계를 구성할 때 그 으뜸음이 된다. ≒서브도미넌트ㆍ하속음.',
#  '고함치는 소리. ',
#  '좋은 말로 구슬리다. ',
#  '병법에 관한 학문.',
#  '‘교사05(校舍)’의 옛말. ',
#  '한 변수가 다른 변수의 식으로 표현됨으로써 독립 변수와 종속 변수가 구별되어 있는 함수. 일반적인 함수를 의미한다. y=2x+3, ',
#  '투표할 수 있는 권리. ',
#  '우산이낏과의 이끼. 헛뿌리가 있어 몸을 땅에 고정시키며 암수딴그루로 암그루의 끝은 갈라진 우산 모양이고 수그루의 끝은 둥글다. 습하고 그늘진 곳에서 자라는데 세계 각지에 널리 분포한다. (Marchantia polymorpha) ',
#  '기간이 정해져 있는 자유형. 형법의 유기 징역, 유기 금고 및 구류 따위이다.',
#  '물체 따위에 반사된 큰 빛이 잠깐 나타나다. 또는 그렇게 되게 하다. ‘번득하다’보다 아주 센 느낌을 준다.',
#  '【…을 …으로】폐품 따위를 용도를 바꾸거나 가공하여 다시 쓰다.',
#  '매우 긴 막대를 강조하여 이르는 말. ',
#  '눈치가 빠르거나, 자기 잇속에 맞게 행동하는 데 재빠르게. ',
#  '여럿이 모두 가운데가 조금 솟아서 볼록하다.',
#  '닥나무 껍질을 원료로 하여 만든 종이. ',
#  '뜸부깃과의 새. 몸의 길이는 22.5cm 정도이며, 머리 위와 목ㆍ가슴ㆍ배는 붉은 갈색이며 다리는 붉은색이고 그 외의 부분은 누런빛을 띤 녹색이다. 논이나 강가의 풀밭에서 사는데 우리나라에는 4월쯤에 날아와 10월 하순까지 머문다. (Porzana fusca)',
#  '슬플 때나 탄식할 때 내는 소리. ',
#  '‘지휘하다’의 옛말. ',
#  '보통의 사람과 유난히 다르다. ',
#  '부시, 부싯깃, 부싯돌 따위를 넣어서 주머니 속에 넣어 가지고 다니는 작은 쌈지. ',
#  '양복의 윗도리.',
#  '돌로 쌓은 탑.',
#  '차별하거나 가리지 않고 마구잡이인. 또는 그런 것.',
#  '심술쟁이 복을 받지 못한다',
#  '【…이】느끼는 바가 있다.',
#  '¶ 그녀는 단 한 권의 소설을 쓰고 절필했으나 권위 있는 문학상까지 탔다.',
#  '‘연자매’의 북한어. ',
#  '-시니. 객체를 높이는 데 쓰인다. ',
#  '위험과 재해를 아울러 이르는 말. ',
#  '꽤 얇다.',
#  '【(…을) …으로】【(…을) -게】단순하거나 등질인 것에서 복잡하거나 이질인 것으로 변하다.',
#  '남이 모르게 지니고 있는 기예. ',
#  '『역사』【(…을)】조선 시대에, 형구를 쓰지 않고 죄인이 신문받다. 또는 그렇게 죄인을 신문하다. 벼슬아치나 양반 사족을 조사할 때 사용하였다.',
#  '사람의 몸을 번쩍 들어 자꾸 내밀었다 들이켰다 하는 일. 또는 던져 올렸다 받았다 하는 일. 기쁘고 좋은 일이 있는 사람을 축하하거나, 잘못이 있는 사람을 벌줄 때 한다. ',
#  ' =비천하다01(卑賤―). ',
#  '【…을】몹시 사랑하다. ≒절애지하다.',
#  '‘가볍다’의 옛말. 모음으로 시작하는 어미 앞에서는 ‘가\ue668\uedc2-’이나 ‘가\ue668야오-’로 나타난다. ',
#  '낮게 대접하는 말을 쓰다.',
#  '【…을】위에서 아래로 쭉 펴다.',
#  '【…을】 속에 있는 것이 드러나도록 헤쳐 벌리다.',
#  '근심되고 두려워지다. ≒우계되다.',
#  '크고 단단한 물건이 맞부딪치는 소리가 나다. 또는 그런 소리를 내다. ‘덜걱이다’보다 조금 센 느낌을 준다.',
#  '일본의 대표적인 현악기. 고양이 가죽이나 개 가죽을 붙인 공명 상자에 기다란 손가락판을 달고 비단실을 꼰 세 줄의 현을 그 위에 친 것으로, 무릎 위에 비스듬히 얹고 발목(撥木)으로 줄을 튕겨 연주한다.',
#  '물관부나 체관부가 서로 붙어 있는 관다발. 겉씨식물, 속씨식물에서 흔히 볼 수 있다. 줄기는 바깥쪽에 체관부, 안쪽에 물관부, 잎은 위쪽에 물관부, 아래쪽에 체관부가 있다. ≒병립 유관속.',
#  '까닭을 모르거나 갈피를 잡을 수 없는 상태를 비유적으로 이르는 말. 감투에는 원래 끈이 없는 데서 유래한다. ',
#  '꺾여 삐치다. ',
#  '‘장도리01’의 옛말. ',
#  '감자가 많이 나는 강원도 지역이나 그 출신 사람을 낮잡아 이르는 말.',
#  '임무나 과업 따위를 맡겨 하게 하다. ',
#  '아주 심한 욕지기. ',
#  ' =서쪽.',
#  '내려갈수록 점점 더 다르다. ',
#  '홀짝술이 사발술[말술] 된다',
#  '교도소에서, 재소자들의 동정을 살피기 위하여 감방 문에 만든 감시 구멍. 긴 네모 모양으로 뚜껑이 달려 있다. ',
#  ' =어스레하다.',
#  '백성을 잘 다스리는 어진 관리.',
#  '‘내걸다[2]’의 피동사. ',
#  '¶ 선차적 사업/선차적 과제∥무엇보다도 이 문제를 선차적으로 해결해야 한다.',
#  '어떤 대상을 이기거나 극복하기 위한 싸움에 관한 내용을 담은 이야기. ',
#  '나무가 우거진 숲. ≒나무새02ㆍ수림02(樹林). ',
#  '‘바스스하다’의 옛말. ',
#  '‘더불다’의 옛말. ',
#  '‘누이다04’의 옛말.',
#  ' =갈도성.',
#  '『법률』‘관할 구역’을 줄여 이르는 말. ',
#  '【…을】 힘 있게 꼭 다물다. ',
#  '((다른 말과 함께 쓰여))',
#  '【…을】 남의 재물을 몰래 훔치거나 빼앗다.',
#  '상을 주다. ',
#  '발로 디디는 데 편리하게 파 놓은 홈. ',
#  '‘휘밀다’의 피동사. ',
#  '감영이나 군아에서 곡물을 출납하고 간수하는 일을 맡아보던 구실아치.',
#  '술과 색에 빠져 방탕하게 놀기를 잘하는 사람을 낮잡아 이르는 말. ',
#  '동태의 내장을 빼고 그 속에 쇠고기, 돼지고기, 숙주나물, 두부, 우거지 따위를 다져 넣고 아가리를 오므려 묶은 다음 꼬챙이에 꿰어 얼린 후 찌거나 끓여서 먹는 음식. ',
#  '범의귓과의 낙엽 활엽 관목. 높이는 2미터 정도이며, 잎은 어긋나고 잎자루가 세 갈래로 얕게 갈라진다. 봄에 작고 흰 꽃이 총상(總狀) 화서로 피고, 열매는 장과(漿果)로 가을에 검붉게 익으며 식용한다. 깊은 산 속에 자라는데 한국, 만주 등지에 분포한다. (Ribes mandshuricum)',
#  '헤매며 떠돌다. ',
#  '한 초소에서 두 사람이 함께 서는 보초(步哨). ',
#  '찾아가다. 추구하다01. ',
#  '사람다운 성질이 있는. 또는 그런 것.',
#  '능력이 있으면서 교활하다.',
#  '¶ 짐 실은 소달구지가 뻐거덕뻐거덕하며 산모퉁이를 돌아간다.∥학생들은 멀쩡한 의자를 뻐거덕뻐거덕하다가 결국 부숴 버렸다.',
#  '예수의 수난을 기념하는 기독교의 의식. 예수의 최후를 기념하여 회중(會衆)이 예수의 살을 상징하는 빵과 피를 상징하는 포도주를 나누어 먹는 의식이다. ≒성만찬',
#  '화채의 하나. 아주 잘게 썬 가래떡에 녹말을 묻힌 다음에 그것을 끓는 물에 삶아 꿀물이나 오미잣국에 넣어 먹는다.',
#  '‘개암01’의 북한어.',
#  '눈동자에 좁쌀만 하게 생기는 희거나 붉은 점.',
#  '‘못단’의 북한어. ',
#  '질투하는 마음. ≒투심01(妬心).',
#  '【…을】 지나간 것을 돌이켜 생각하다.',
#  '노랑, 빨강, 파랑 따위의 색깔이 있는 분필. ',
#  '의지하고 지내던 곳에서 가진 것 없이 쫓겨난 사람. ',
#  ' =꺼풀지다. ',
#  '눈이 내려 쌓였을 때의 경치. ',
#  '관리에게 적용하는 규칙. ',
#  '일, 지식 따위가 아주 오래되어 시대에 뒤떨어진 데가 있다. ',
#  '¶ 뜨끈한 술국이나 푸짐하게 뜨고 막걸리 한 방구리만 내오게.≪송기숙, 녹두 장군≫',
#  '한쪽의 의사만이 행세하거나 통하는 일을 비유적으로 이르는 말. ',
#  '【…을】 물건을 창고에 넣고 굳게 봉하여 쓰지 못하도록 하다.',
#  '온도가 매우 높아 더운 모양.',
#  '‘왜여모기’의 옛말. ',
#  '바늘땀을 드문드문 거칠게 자꾸 호다. ‘숭덩거리다「2」’보다 센 느낌을 준다. ≒쑹덩대다.',
#  '다시 투표하다.',
#  '트림하는 소리가 자꾸 나다. ≒끌끌대다02.',
#  '기술이 뛰어나 이름난 장인.',
#  '물의 근원. ',
#  '단원제 국회의 의원(議院). 상원과 하원으로 구분하지 아니하고 하나만 둔다. ≒일원03(一院).',
#  '¶ 섬돌 밑엔 낯선 구두가 두 켤레 가지런히 놓여 있었다.≪최일남, 거룩한 응달≫【',
#  '‘옮다[2]「2」’의 사동사.',
#  '조선 시대에, 형조와 지방 관아에서 사법 행정의 실무와 교육을 맡아보던 종구품 벼슬.',
#  '어리둥절하여 얼빠진 사람처럼 멍하다.',
#  '말이나 소 따위의 앞쪽 발굽.',
#  '어떤 일에 대하여 언짢은 말이나 소문을 비유적으로 이르는 말. ',
#  '반동 터빈의 날개 바퀴 주위에 물을 잘 대 주기 위하여 설치하는 타래진 관.',
#  '나무의 껍질. ≒목피02. ',
#  '머리뼈 바닥과 옆면의 중간 부분에 있는 불규칙한 뼈. 뼈 속에 가운데귀와 속귀가 있으며 아래쪽은 아래턱뼈와 관절을 이룬다. ≒섭유골ㆍ옆머리뼈ㆍ측두골.',
#  '임금이 직접 명령을 내리어 벼슬을 맡기다.',
#  '아들도 딸도 없다. ≒무자하다01.',
#  '강냉이눈으로 기름을 짜고 남은 깻묵. 기름 성분이 많아 집짐승의 먹이로 쓰기에 좋다.',
#  '【…을】죽음을 각오하고 간하다. 또는 죽음으로써 간하다.',
#  '색과 무늬가 없는 흰옷.',
#  '긁어 빗기다. ',
#  '(예스러운 표현으로) 해라할 자리에 쓰여, 진리나 으레 있는 사실을 추측하여 일러 줄 때에 쓰는 종결 어미.',
#  '¶ 기차표를 개찰하다.',
#  '의사가 환자를 진찰하는 방. ',
#  '강연이나 설교, 음악 따위를 듣기 위하여 모인 사람들이 앉는 자리. ',
#  '하늘이 맑고 밝으며 날씨가 몹시 차다.',
#  '【…을】 까부라지게 하다.',
#  '수나 양이 늘어 더 강하게 되다.',
#  '‘토끼’의 옛말. ',
#  '¶ 눈이 깜빡깜빡하다∥아이는 눈을 깜빡깜빡하며 멍청하게 앉아 있었다.',
#  '문기03「1」',
#  '조금 기운 듯하다.',
#  ' =겨레붙이. ',
#  '삼복(三伏)이 든 시기.',
#  '‘창유리’를 달리 이르는 말.',
#  ' =도파니. ',
#  '‘여봐라’의 본말. ',
#  '¶ 국수배와 술배/밥 배와 국수배는 따로 있다.≪선대≫',
#  '날아서 공중으로 오르다.',
#  '고깔 뒤의 군 헝겊',
#  '되로 주고 말로 받는다',
#  '문제점을 찾아서 그에 적극적으로 대처하려는 태도. ',
#  '온몸이 입이라도 말 못하겠다',
#  '밭에 심어 기르는 벼. 볍씨를 뿌려 가꾸는데 알이 굵고 잘 여문다. ≒산도04(山稻)ㆍ육도08(陸稻)ㆍ한도01(旱稻).',
#  '‘-으려고 하느냐’가 줄어든 말.',
#  '두 가지의 사물이나 사람을 들어 말할 때, 먼저 든 사물이나 사람.',
#  '【…을】 ‘깨다02’를 강조하여 이르는 말. ≒깨트리다.',
#  '대구과의 바닷물고기. 몸의 길이는 70~75cm이고 넓적하며, 엷은 회갈색에 배는 흰색이다. 입은 크고 비늘은 작고 둥근 모양이다. 고기는 식용하고 간은 간유의 원료로 쓴다. 한국, 일본, 베링 해, 미국 등지에 분포한다. ≒대구어ㆍ대두어. (Gadus macrocephalus) ',
#  '찬물로 습기를 가한다는 뜻으로, 옥수수를 보통 온도의 물에 불리는 일을 이르는 말. 옥수수 가공을 위한 예비 처리의 하나이다.',
#  '어떤 사물이나 현상 본래의 느낌.',
#  '생생한 피. ≒선지피. ',
#  '통곡하는 소리. ',
#  '꽤 넓다.',
#  '크고 단단한 물건이 맞부딪치는 소리가 자꾸 나다. 또는 그런 소리를 자꾸 내다. ‘덜거덕거리다’보다 아주 센 느낌을 준다. ≒떨꺼덕대다.',
#  '담쌓고 벽 친다',
#  '살충제의 해충을 죽이는 힘. ',
#  '초가지붕에서 양쪽 추녀를 조금씩 잘라서 처맛기슭을 둥그스름하게 하다. 귀에 오는 이엉을 둥글게 덮기 위해서 한다.',
#  '양말 위에 덧신거나 맨발에 신는, 목 없는 버선. ',
#  '「2」ㆍ난봉쟁이ㆍ놀량패ㆍ유랑02(劉郞)ㆍ표객. ',
#  '하는 일 없이 공연히 바쁘게.',
#  '‘출행(出行)’의 옛말. ',
#  '‘앵두’의 옛말. ',
#  '씩씩하고 굳센 기상과 진취적인 정신. ',
#  '【…을】 나누지 아니하고 한곳에 합치다. ',
#  ' =나무총.',
#  '버스를 타기 위하여 돈을 주고 사는 표. ',
#  '꽤 단단한 물건을 깨물어 부스러지는 소리가 잇따라 나다. 또는 그런 소리를 잇따라 내다. ≒으적대다.',
#  '【…에서/에게서 …을】잃거나 맡기거나 빌려 주었던 것을 돌려받아 가지고 가다.',
#  '도척의 개 범 물어 간 것 같다',
#  '가볍고 경망스럽게 자꾸 까불다. ‘졸랑거리다「2」’보다 센 느낌을 준다. ≒쫄랑대다.',
#  '¶ 그때 선발한 첫 차가 지금 어디쯤이나 와 있는가를 묻기 위함이었다.≪허준, 잔등≫',
#  ' 『북』「1」재앙이나 화가 미치다.',
#  '석유를 정제할 때 잔류물로 얻어지는 고체나 반고체의 검은색이나 흑갈색 탄화수소 화합물. 유전에서 천연으로 얻을 수도 있으며 가소성, 접착성, 탄성, 전성, 전기 절연성 따위가 풍부하다. 도로포장, 방수, 방습의 재료로 쓴다. ≒역청ㆍ지역청ㆍ토역청ㆍ피치(pitch)[Ⅰ]「10」. ',
#  '앞말이 나타내는 상황이 사실임을 인정하여 양보하는 뜻을 나타내는 연결 어미.',
#  '【(…을)】크고 묵직한 물체나 몸이 중심을 잃고 한쪽으로 기울어지다. 또는 그것을 한쪽으로 기울이다.',
#  '어질고 후덕하다. ',
#  '어떤 일이 가장 활기 있고 왕성하게 일어나는 모양. 또는 어떤 상태가 가장 무르익은 모양. ',
#  '두 사람.',
#  '어떤 행위를 하지 못하게 저지되다.',
#  '입을 조금 벌리고 힘없이 내는 소리. 또는 그 모양.',
#  '(예스러운 표현으로) 자기를 낮추면서 상대편에게 공손하게 대하는 뜻을 나타내는 어미. ‘-자옵-’에 주체에 대한 존대를 나타내는 ‘-시-18’가 결합한 말이다. ‘-으시-01’보다 극진한 존대를 나타낸다.',
#  '잡은 물고기 따위를 급속히 얼리는 시설을 갖추고 있는 냉동선. ≒급동선.',
#  '어떤 일을 하는 데 필요한 비용 따위를 계산하여 구체적으로 적은 서류. ‘추산서’로 순화. ',
#  '대기 중에서 높이가 같은 주위보다 기압이 높은 영역. 하강 기류가 생겨 날씨가 맑다. ≒고압.',
#  '【…을】반대하는 세력이나 기세를 억눌러 안정되게 하다.',
#  '‘막06(膜)’의 옛말. ',
#  '옛 중국에서, 천자의 생일을 기념하던 날. ≒만수절.',
#  '일이 되고 안 됨. ≒성부01(成否). ',
#  ' =긁적거리다.',
#  '확실하게 말하다.',
#  '‘어이구머니’의 준말.',
#  '주리를 트는 형벌.',
#  '보병목으로 지은 옷. ',
#  '소견이 좁고 융통성이 없는 사람. ',
#  '비린내 맡은 강아지 매 맞아 허리가 부러져도 뜨물통 앞에 가서 죽는다',
#  '종이 따위를 잇따라 바르거나 덧붙이다.',
#  '기이하다02. 신기하다01. ',
#  '‘남상06’의 북한어. ',
#  '평범하고 나약하다.',
#  '‘모다기모다기’의 준말.',
#  ' 「준」철썩철썩하다.',
#  '꾸준하고 부지런하다.',
#  '큰북 따위를 막대기로 가볍게 잇따라 두드리는 소리가 나다.',
#  '【…을】손톱이나 날카로운 물건 따위로 계속 긁어 조금 헤치다.',
#  '주문을 받은 물품. 또는 주문하여 맞춘 물건.',
#  '【…에】전쟁이나 경기 따위를 치르기 위하여 진을 치다. ≒포열하다01.',
#  '어떤 쪽으로 남의 마음을 기울게 하다. ',
#  '척추동물의 표피가 경단백질인 케라틴으로 되다. 비늘, 털, 뿔, 손톱 따위가 이러한 과정을 겪어 만들어진다. ≒각화하다01.',
#  '남에게 일정한 세를 받기로 하고 집이나 물건 따위를 빌려 주다. ',
#  '남을 해치거나 죽이려는 무시무시한 기운.',
#  '전과는 다른 새로운 방면. ',
#  '남보다 훨씬 뛰어나다.',
#  '¶ 냄비에서 물이 끓고 있다./그는 쌀을 여러 번 씻은 뒤 냄비에 안쳤다.',
#  ' =달발. ',
#  ' =밤차.',
#  ' =움쩍거리다.',
#  '¶ 새로 부대에 전입해 온 새파란 소위들은 으레 골탕을 먹곤 한다.∥두 사람이 내가 있는 중대 본부로 전입해 왔다.',
#  '모조리 잡아 없앨 수 있는 대책. ',
#  '맑거나 산뜻하지 아니하고 꽤 흐리어 침침하다. ',
#  '「2」ㆍ휘필하다.',
#  '전선이나 선로를 통하지 못하게 하다.',
#  '사람을 잡아먹음. ',
#  '‘아랫도리01’의 북한어. ',
#  '거리01. 골목01. ',
#  '반동을 일으키는 사람.',
#  '‘수영복’의 북한어.',
#  '봄철이 시작하다.',
#  '【…을】걸을 때에 잇따라 다리를 몹시 절다. ‘절룩절룩하다’보다 센 느낌을 준다.',
#  '『한의학』‘「1」’의 줄기를 말린 것. 성질이 차고 오줌을 잘 누게 하는 작용이 있으며 임질(淋疾)과 부종(浮腫)에 쓴다. ≒통초01(通草)',
#  '이십사절기의 하나. 소만(小滿)과 하지(夏至) 사이에 들며, 이맘때가 되면 보리는 익어 먹게 되고 모를 심게 된다. 6월 6일 무렵이다. ',
#  '흩날리는 불꽃을 비유적으로 이르는 말. ',
#  '사람이 세상을 살아가는 생활.',
#  '예전에, 다른 고장에서 만난 같은 서울 사람을 이르던 말. ',
#  '요사스러운 첩. ',
#  '승하게. 낫게. ',
#  '신빙성 있는 증거로 삼아지다.',
#  '뜸부깃과의 여름새. 몸의 길이는 35cm 정도이며, 색깔은 암수가 약간 다른데 부리는 누런색이고 등은 검누런 갈색이다. 날개는 검은색으로 넓은 아롱무늬가 있고 다리는 녹색이다. 부리와 다리가 길며 호수나 하천 등지의 갈대숲이나 논에서 살며 ‘뜸북뜸북’ 하고 운다. 동북아시아에서 번식하고, 동남아시아에서 겨울을 보낸다. ≒등계(䳾鷄)ㆍ팟다리. (Gallicrex cinerea)',
#  '【…을】 거볍게 곁눈질하여 자꾸 슬쩍슬쩍 쳐다보다. ≒힐금대다.',
#  '‘나’ 음을 으뜸음으로 한 장조.',
#  '자는 체하느라고 일부러 고는 코.',
#  '‘잊다01’의 옛말. ',
#  '나무숲 속.',
#  '금속 산화물이 환원할 때에 산소가 빠지는 비율. 곧 본디 산화물의 산소량에 대한 환원 이후 없어진 산소량의 비율을 이른다.',
#  '건설 공사 따위의 수주에서 여러 기업체가 공동으로 참여하는 방식. 또는 그런 모임. ',
#  '뜻이나 결과가 같은. 또는 그런 것. ',
#  '비둘기가 자꾸 울다. ≒꾹꾹대다.',
#  '시세의 변화. 또는 그때의 변고. ',
#  '【…을】 임금이 밤에 독서하다. 임금이 낮에는 정사를 보고 자기 전인 을야(乙夜), 곧 밤 10시부터 12시까지 책을 읽는다고 하여 생겨난 말이다.',
#  '‘맨몸「2」’을 속되게 이르는 말. ',
#  '‘부끄러이’의 옛말. ',
#  '여러 사람이 한데 모여 자꾸 수선스럽게 지껄이다.',
#  '남이 알아차리지 못할 정도로 슬며시 재빠르게.',
#  '호구 조사하는 칼치 장사',
#  '보기에 가냘프고 약하면서 졸망하다. ',
#  '여기저기서 잇따라 갑자기 솟아올라 불룩불룩하다.',
#  '걱정이 없고 평안한 운수.',
#  ' 「준」철컥철컥하다.',
#  ' =학과 과정. ',
#  '양은으로 만든 그릇. ',
#  ' =속내.',
#  '【…을】 =비죽거리다.',
#  '민요의 가락을 띤 형식. ',
#  '물방울 따위가 겉에서 작은 방울로 맺히다. ',
#  '【…을】 =모방하다.',
#  '종이, 피륙, 천 따위의 반 폭. ',
#  '지폐 또는 돈이나 물품과 교환될 수 있는 종이로 된 증서가 발행되다.',
#  '남의 아이에게 그 어머니 대신 젖을 먹여 주는 여자. ≒유온(乳媼)ㆍ젖어머니. ',
#  '귀가 먹먹할 정도로 높고 강하게 울리는 소리가 나다.',
#  '【…을】정식 성원이 아니거나 직접적인 관계가 없는 사람이 회의, 토론, 연설, 공판(公判), 공개 방송 따위에 참석하여 듣다.',
#  '‘켜이다02’의 준말. ',
#  '‘-을 정도로’의 뜻을 나타내는 연결 어미. ≒-으리만치.',
#  '거듭된 재난. 또는 온갖 재난. ',
#  '표 따위에 구멍을 뚫다. ',
#  '‘연싸움’의 옛말. ',
#  '【…을】어루만지고 잘 달래어 시키는 말을 듣도록 하다.',
#  '김 씨가 한몫 끼지 않은 우물은 없다',
#  '수술을 하려고 절단한 자리나 외상(外傷)으로 갈라진 자리를 꿰매어 붙이다.',
#  '쓰임에 알맞은 분량. ≒적량01(適量). ',
#  '세로로 꿰매다.',
#  '된장을 푼 물에 미꾸라지를 갈아 넣고 우거지 따위와 함께 끓인 국. ≒미꾸라짓국.',
#  '톱질을 하는 일손. ',
#  '【…을】반드시 납부하다. 또는 납부하여야 하다. ',
#  '신문의 지면.',
#  '복의 이 갈듯',
#  '‘어떤 사물이나 특성을 많이 가진 사람’의 뜻을 더하는 접미사.',
#  '¶ 꼬마는 더 싸우라고 친구들 싸움에 키질하고 있었다.',
#  '하루 가운데 저녁때. ',
#  '‘에게「3」’의 높임말. ',
#  '¶ 돌상을 차리다/돌상 위에는 아기가 집으라고 연필이며 국수며 돈 따위를 올려놓는다.',
#  '소 두 마리가 끄는 가대기의 멍에. 하나의 긴 통나무로 되어 있다. ',
#  '되는대로 마구. ',
#  '『옛말』‘어금니’의 옛말. ',
#  '뻐꾸기도 유월이 한철이라',
#  '‘덮개’의 옛말. ',
#  '특정한 사람에게만 호의를 보이다.',
#  '절개나 지조를 깨뜨리다.',
#  '안쪽으로 아무렇게나 막 집어넣다. ≒들이트리다.',
#  '「2」ㆍ석문08(釋門)ㆍ석씨(釋氏)',
#  '저녁때의 경치.',
#  '자갈. 조약돌. ',
#  '이쪽저쪽 어긋나게 마주 있다. ',
#  '국화과의 두해살이풀. 높이는 30~50cm이며, 잎은 어긋나고 타원형의 피침 모양이다. 5~8월에 홍자색 꽃이 가지 끝에 하나씩 피고 열매는 수과(瘦果)를 맺는다. 어린잎은 식용하고 줄기와 뿌리는 약용한다. 한국, 일본, 중국 등지에 분포한다. ≒조방가새. (Cirsium segetum)',
#  '겨를. 또는 틈. ',
#  '나갔다가 들어왔다가 하는 어귀나 문. ',
#  '「1」힘이나 재료가 적게 들어가도 결과만 좋으면 됨을 비유적으로 이르는 말.',
#  '불가사리01「1」',
#  '나라를 대표하여 다른 나라에 파견되어 외교를 맡아보는 최고 직급. 또는 그런 사람. 주재국(駐在國)에 대하여 국가의 의사를 전달하는 임무를 가지며 국가의 원수와 그 권위를 대표한다. ≒전권 대사ㆍ특명 전권 대사.',
#  '【…을 …에】달아나지 못하도록 엄중하게 가두다.',
#  '음력 보름께.',
#  '매우 잔 알갱이.',
#  ' =막일하다.',
#  '크게 느끼어 마음이 움직이는. 또는 그런 것.',
#  '‘밥01’의 옛말. ',
#  '국화과의 여러해살이풀. 높이는 30㎝ 정도이며, 근생엽은 뭉쳐나고 깃 모양으로 갈라지며 경엽은 어긋난다. 9~10월에 흰색 꽃이 줄기 끝에 하나씩 핀다. 바닷가 산지(山地)에서 자라는데 울릉도 특산종이다. 천연기념물 정식 명칭은 ‘나리동(羅里洞)의 울릉국화, 섬백리향 군락’이다. 섬백리향과 더불어 천연기념물 제52호이다. (Chrysanthemum lucidum) ',
#  '사랑채에 딸린 하인. ',
#  '‘무던히’의 옛말. ',
#  ' =봄비. ',
#  '병으로 죽다.',
#  '현실적으로 지출이 가능한 금액. ',
#  '초계에 사용하는 함정. ≒초정03(哨艇).',
#  '멧돼짓과의 하나. 어깨의 높이는 60cm, 몸의 길이는 1미터 정도로 멧돼지와 비슷한데, 네 다리가 다소 길고 털이 없으며 몸빛은 암회색이다. 수컷은 아래 송곳니가 코끼리 이빨 모양으로 30cm 정도이며, 안쪽 살가죽을 뚫고 바깥쪽으로 나온 진기한 모양을 하고 있다. 야행성이며, 술라웨시 섬ㆍ부루(Buru) 섬ㆍ몰루카 제도 등지에 분포한다. (Babirousa babyrussa)',
#  '같은 비율. 또는 같은 비례. ',
#  '‘비거덕거리다’의 준말. ≒비걱대다.',
#  '농사꾼이나 일꾼들이 끼니 외에 참참이 먹는 음식.',
#  '큰 벌레 따위가 매우 좀스럽고 굼뜨게 움직이다. ≒우무적대다.',
#  '썩 치우쳐 박힌 구석 자리.',
#  '덕판02「1」',
#  '절지동물의 머리 부분에 있는 감각 기관. 후각, 촉각 따위를 맡아보고 먹이를 찾고 적을 막는 역할을 한다. ≒안테나',
#  '부풀의 낱개.',
#  '‘연동척’의 북한어.',
#  '강가에 있는 정자. ',
#  '통발이낏과의 이끼. 잎의 등 편, 배 편, 배엽의 끝은 배 쪽으로 굽어 들지 않는다. 등 편은 달걀 모양으로 1~5개의 톱니가 있으며, 배 편은 좁은 혀 모양으로 두 개 또는 여러 개의 톱니가 있다. 산지의 습기 있는 바위에서 자란다.',
#  '【…에/에게 …을】부탁하여 맡기다. ≒청촉하다.',
#  '익숙하지 못하고 서투르다. ',
#  '작은 일에도 꼼꼼하게 주의를 기울여 빈틈이 없다.',
#  ' =각수03(刻手).',
#  '땔나무를 하는 아이. ≒초수06(樵豎). ',
#  ' =비탄01(飛彈). ',
#  '산소를 지키며 보살피는 사람. ≒뫼지기ㆍ묘노(墓奴)ㆍ묘직(墓直)ㆍ수총02(守塚)ㆍ총호01(塚戶). ',
#  '묵은 솜을 둔 도포.',
#  ' =이기죽거리다.',
#  '몸이나 마음이 편하지 않고 고통스럽게.',
#  '【…을】우러러 받들다. ≒앙승하다.',
#  '나비 모양의 노리개 밑에 다시 호리병을 단 삼작노리개. ',
#  '『북한어』해가 중천에 떠 있는 때. ',
#  ' 「비」「1」낙제하다',
#  '슬프게 하소연하다. ≒애호하다01.',
#  '혁명과 건설에서 발생하는 모든 문제를 대중의 창조력을 동원하여 구체적 실정에 맞게 독창적으로 풀어 나가는 태도.',
#  ' 「비」순행하다04.',
#  '【…을】 결코 못지않다. 또는 비견할 만하다. ',
#  '부서진 갓모자가 되었다',
#  '집을 팔고 사는 값. ',
#  '몸가짐이 조심스럽고 얌전하다.',
#  '‘시기03(時氣)’의 옛말. ',
#  '생물의 씨가 아주 없어지다.',
#  '동학의 교구 또는 집회소. ≒접06(接). ',
#  '말이나 행동이 분수에 맞지 아니할 정도로 지나치게.',
#  '눈과 입을 살며시 움직이며 소리 없이 정답고 환하게 웃다.',
#  '주로 동력으로 움직이는 자동차나 열차 따위가 달리다.',
#  '『옛말』‘도투마리01’의 옛말. ',
#  ' 유난히 날카로운 소리를 지르다.',
#  '제낀깃을 한 형태. ',
#  '축구, 핸드볼 따위의 운동 경기에서, 경기 시간을 반씩 둘로 나눈 것의 앞쪽 경기.',
#  '(예스러운 표현으로) 자신의 행동을 의식적으로 드러내어 나타내는 종결 어미.',
#  '뇌물의 성격을 띠거나 그 밖의 정당하지 못한 방법으로 주고받는 돈을 이르는 말. ',
#  '새해의 복이나 기쁨. ≒신지11(新祉). ',
#  '¶ 다 늙게 젖먹이를 기른다는 것은 뼛골이 빠지는 일이지마는 앞에서 곰실곰실하는 것이 나날이 커 가고, 낯을 알아보고 하는 것을 보면 저절로 웃음도 나오지 않을 수 없었다.≪염상섭, 부성애≫',
#  '넘어지거나 기울어지지 아니하도록 뒷면에 대는 받침대. ',
#  '주름버섯과의 버섯. 가장자리가 말려들어 흰색의 갓을 만들며 털이 있고, 뒷면은 분홍색 또는 연주황색의 쪼글쪼글한 주름이 나 있다. 식용하며, 여름부터 가을에 걸쳐 풀밭, 밭, 잔디밭에서 자란다. (Agaricus campestris) ',
#  '수축하여 몸이나 몸의 부분을 움직일 수 있도록 특성화된 조직. 근육 섬유, 근육 세포, 결합 조직과 세포 외 조직으로 구성되어 있다. ≒근조직.',
#  '수효가 많다.',
#  '마음과 힘을 다하여 떨쳐 일어나려는 마음. ',
#  '양의(洋醫)와 한의(韓醫)를 아울러 이르는 말. ',
#  '항공 수송을 위하여 사용하는 공공용 비행장. 주로 민간 항공기와 같은 정기 항공기의 이착륙에 사용한다. 일반 여객과 화물의 수송을 주목적으로 하며 활주로, 유도로, 관제탑, 격납고, 급유ㆍ정비 시설, 여객ㆍ수하물ㆍ화물을 처리하는 시설 따위를 갖추고 있다. ≒항공항(航空港). ',
#  '【…을】익살스러운 것이 되게 하다.',
#  ' =측근자. ',
#  '‘용가자미’의 북한어.',
#  ' =월동. ',
#  '‘움켜쥐다’의 피동사. ',
#  '포로나 불법으로 입국한 사람 등이 본국으로 도로 돌려보내어지다.',
#  '무엇을 움직이게 하거나 부리어 쓰는 데 드는 비용.',
#  '‘적운’의 북한어. ',
#  '굽거나 찌기 위하여 돌로 쌓아서 만든 구덩이. ',
#  '¶ 인류의 기원은 200만 년 전으로 소급해 올라간다.∥그 매매 증서를 법에 저촉되지 않게 작년 시월 이전으로 소급하여 작성하느라고 읍사무소에도 적지 않은 푼돈을 썼다.≪김원일, 불의 제전≫',
#  ' =등사하다.',
#  '물품을 대량으로 만드는 사업. ',
#  '대륙에 있는 물의 여러 가지 상태를 연구하는 학문. 수문학의 한 분야이다.',
#  '【…을】 =목격하다.',
#  '제일 잘 만듦. 또는 그런 성과물. ',
#  '주책없이 쏘다니다. ',
#  '-세. ',
#  ' =모손되다.',
#  '서로 마주 보이는 방향.',
#  '(예스러운 표현으로) 합쇼할 자리에 쓰여, 동작이나 상태에 대한 의문을 나타내는 종결 어미. 공손함을 나타내는 어미 ‘-으오-01’에 의문을 나타내는 어미 ‘-ㅂ니까’가 결합한 말이다.',
#  '【…을】 전체적인 일을 묶어서 보살피고 단속하다.',
#  ' =음풍농월하다.',
#  ' =음지쪽. ',
#  '이용한 값으로 내는 요금.',
#  '‘연성01(延性)’의 북한어.',
#  '생각한 바를 실제로 행하는. 또는 그런 것.',
#  '여러 가지 빛깔의 크고 뚜렷한 점이나 줄 따위가 고르지 아니하고 조금 성기게 무늬를 이룬 상태이다.',
#  '스케이트「1」',
#  '단을 쌓다.',
#  '((몇몇 형용사 앞에 붙어))‘어지간한 정도로 대충’의 뜻을 더하는 접두사. ',
#  '조선 인조 6년(1628)에 유효립(柳孝立)의 역모(逆謀)를 고한 이에게 내린 훈명(勳名). 허적(許',
#  '지나간 때에.',
#  '지체 없이 곧. ',
#  '【…을】 함부로 마구 싸대다. ',
#  '대개 조러하여 별로 특별하지 않다.',
#  '‘돌서덜’의 북한어. ',
#  '크고 단단한 쇠붙이 따위가 맞부딪쳐 울리는 소리가 나다. 또는 그런 소리를 내다.',
#  '쌀을 국에 넣어 끓인 음식. ',
#  '밤나방과의 곤충. 편 날개의 길이는 2.6~3.2cm이며 머리, 가슴, 몸은 누런 갈색, 꼬리 부분은 잿빛 누런색이다. 앞날개는 연한 잿빛 갈색인데 진한 비늘이 있다.',
#  '‘얼룩’의 옛말. ',
#  '아씨들 가운데 맨 위의 아씨가 아닌 아씨를 이르는 말. ',
#  '‘용접 토치’의 북한어.',
#  '‘궁둥이’의 옛말. ',
#  ' =너부죽01.',
#  '『북한어』‘윽죄다「2」’의 피동사. ',
#  '어떤 물품을 배급하는 제도. ',
#  '‘중독자’를 낮잡아 이르는 말.',
#  '점점 불어서 쌓이고 늘어나다.',
#  '썰물 때 멀리까지 드러나는 개펄. ',
#  '바닥이 낮고 습기가 많다. ',
#  '사람이 변변하지 못하고 졸렬한 데가 있게.',
#  '‘쩔거덩하다’의 준말.',
#  '인정이 없이 매정하거나 쌀쌀하다.',
#  '‘넷01’의 옛말. 휴지(休止) 앞에서는 ‘ㅎ’이 탈락하여 ‘네’로 나타난다. ',
#  '몹시 놀라 넋을 잃다. 혼백이 어지러이 흩어진다는 뜻에서 나온 말이다. ≒백산하다ㆍ혼불부신하다.',
#  '쓸데없는 말을 자꾸 지껄이다.',
#  '앞으로 일어날 일이 미리 알려지다.',
#  '승려가 머리에 쓰는 관(冠). 약탕관을 엎어 놓은 것같이 위가 둥그스름하다. ',
#  '교태가 있고 요염하다. ',
#  '음식을 절제하여 먹거나 간소하게 먹다.',
#  '사물이 일정한 질서를 갖고 유기적인 활동을 하게끔 통일이 이루어지다. 또는 그렇게 하다.',
#  '뒤쪽에 있는 벽. ≒후벽(後壁). ',
#  '바둑에서, 비기는 일을 없애기 위하여 덤을 ‘여섯 집 반’ 또는 ‘일곱 집 반’으로 규정함으로써 생기는 계산상의 집. ≒반호01(半戶). ',
#  '철교「1」',
#  '이 층으로 지은 집. ≒중옥01(重屋). ',
#  ' =그쪽.',
#  '마디풀과의 한해살이풀. 줄기는 높이가 40~80cm이며, 온몸에 잔털이 있다. 잎은 어긋나고 피침 모양이며 끝이 뾰족하다. 7~8월에 연두색 또는 연분홍색의 꽃이 가지 끝에 수상(穗狀) 화서로 피고 열매는 수과(瘦果)를 맺는다. 꽃대 윗부분은 점액질이 분비되어 끈끈하다. 산이나 들에서 자라는데 우리나라 각지에 분포한다. (Persicaria viscofera) ',
#  '크고 묵직한 물건이 깊은 물에 떨어져 잠기는 소리가 나다. 또는 그런 소리를 내다.',
#  '천연두의 증세. ',
#  '진리나 사실, 입장 따위가 드러내어져 밝혀지다.',
#  '자기의 감정이나 욕심, 충동 따위를 이성적 의지로 눌러 이기다.',
#  '고기나 수산물 따위를 잡거나 거두어들이다.',
#  '【…을】 임금을 폐하고 새로 다른 임금을 맞아 세우다.',
#  '‘논다니’의 옛말. ',
#  ' =화관(花冠).',
#  '관리의 직책에서 물러나게 되다.',
#  '¶ 량소명월을 읊조리다.',
#  '여러 사람이 차례로 돌려 보도록 쓴 글. ≒첩장02(牒狀)ㆍ회문. ',
#  ' =괘종시계. ',
#  '‘휘지다01’의 옛말. ',
#  '‘위성류’의 옛말. ',
#  '제도적 정치 조직 속에 들어가지 못하는 처지에 있는 사람. ',
#  '여러 사람이 두루 알게 되다.',
#  '¶ 몸이 노긋해서 그런지 입맛도 없고 속도 안 좋다.',
#  '수평이나 수직이 되지 아니하고 한쪽으로 조금 기운 듯하다.',
#  '돌을 맞은 아기의 허리에 매어 주는 띠. 수명장수를 기원하는 뜻에서 한 바퀴 돌려 맬 수 있도록 길게 만든다. ',
#  '미꾸릿과의 민물고기. 몸의 길이는 15~17cm이고 옆으로 납작하며, 누런색이다. 옆쪽에는 어두운 갈색 무늬가 있고 배 쪽에는 암갈색 무늬가 있다. 주둥이는 길다. 우리나라 특산종으로 한강, 임진강의 중ㆍ상류에 분포한다. (Cobitis rotundicaudata)',
#  '녹나뭇과의 상록 활엽 교목. 높이는 20미터 정도이며, 잎은 어긋나고 긴 타원형인데 두껍고 윤이 난다. 5~6월에 노란색을 띤 녹색 꽃이 가지 끝에 원추(圓錐) 화서로 피고 열매는 장과(漿果)로 다음 해 7월에 검은빛을 띤 자주색으로 익는다. 나무껍질은 염료와 약재로, 목재는 가구재와 선박재로 쓴다. 한국의 남부, 일본의 오키나와, 대만, 중국 남부 등지에 분포한다. (Machilus thunbergii) ',
#  '비가 오기 직전에 급하게 불어오는 사나운 바람.',
#  '삼가 편지를 드린다는 뜻으로 봉투에 쓰는 말. ',
#  '팔다리를 마음대로 잘 놀리지 못하고 천천히 부자연스럽게 조금씩 겨우 걷다. ≒아기족대다.',
#  '뛰어난 명성이나 명예. ',
#  '병이 심하여 위험한 상태. ',
#  '지루하게. ',
#  ' =찌르륵거리다02. ',
#  '코끝 양쪽으로 둥글게 방울처럼 내민 부분. ',
#  '서태평양 중부의 나우루 섬에 있는, 세계에서 가장 작은 공화국. 제일ㆍ이 차 세계 대전을 거치면서 유엔 신탁 통치 지역이었다가 1968년에 독립하였다. 주민은 해안 지대에 밀집하여 살며 인광석(燐鑛石)이 많이 난다. 수도는 야렌이다. 면적은 22㎢.',
#  '‘메밀가루’의 옛말. ',
#  '찾아오는 사람이 많아 집 문 앞이 시장을 이루다시피 함을 이르는 말. ≪한서≫의 에 나오는 말이다.',
#  '국제적ㆍ국내적으로 여러 가지 경제 활동이 뚜렷하게 교류되고 있는 일정한 범위 안의 지역. ',
#  '풀과 나무와 날짐승과 길짐승을 아울러 이르는 말. 온갖 생물을 이른다. ',
#  '기름을 담아 불을 켜는 등잔. ',
#  '꾸지뽕을 먹고 사는 누에. ',
#  '【…을】 공사를 시작하다.',
#  '((액수를 나타내는 명사 뒤에 붙어))‘지폐’의 뜻을 더하는 접미사. ',
#  '막술에 목이 멘다',
#  '비둘깃과의 새. 암수가 비슷하며, 몸은 포도색을 띤 회갈색이다. 목의 옆에는 청회색과 흑색의 무늬가 있으며, 꼬리는 흑갈색으로 끝에 회백색의 무늬가 있다. 부리는 어두운 잿빛이고 다리는 암적색이다. 눈의 홍채는 등갈색을 띤다. 정원, 산림, 나무가 있는 곳에서 흔하게 번식하며 작은 나뭇가지로 엉성하게 둥지를 만들고 2개의 알을 낳는다. 시베리아 남부, 사할린, 한국, 일본, 중국, 히말라야 등에 분포한다. ≒골구ㆍ산구02ㆍ산비둘기. (Streptopelia orientalis)',
#  '¶ 예전에는 옹구로 거름을 날랐는데 지금은 경운기로 나른다.',
#  '말하다. 이르다02. ',
#  '국가 예산 수입의 하나. 사회주의 국영 기업소나 기관에서 이루어진 사회 순소득의 분배 형태로, 국가 예산 수입의 기본 부문을 이룬다.',
#  '「1」한 짓이 너무 지나쳐서 반드시 보복을 당하리라는 것을 이르는 말.',
#  '늘 분주하게 이리저리 떠돌아다니는 사람을 이르는 말. ',
#  '자본주의 제도하에서 대량 생산에 의하여 파산ㆍ몰락하는 수공업자, 농민 등 소시민 계층의 이익을 반영하여 생겨난 사상 조류. 자본주의를 비판하지만 이전의 소농민 경리 또는 소상품 생산을 이상화하고 모든 사회관계를 예전의 소유관계로 다시 돌리려고 한다.',
#  '‘낮도깨비「1」’의 북한어. ',
#  '땅에 괸 물을 빠지게 하거나 땅의 경계를 표시하기 위하여 얕게 판 작은 도랑. ',
#  '액체를 증류할 때 쓰는 냉각기. 가는 유리관과 관을 둘러싼 외통(外筒)으로 되어 있으며, 외통과 유리관 사이로 물이 흘러 유리관 안을 통과하는 증기를 냉각하고 액화하는 데 쓰인다. 독일의 화학자 리비히가 고안하였다. ',
#  '불만스럽거나 못마땅하여 성난 빛이 얼굴에 나타나게.',
#  '다른 산의 나쁜 돌이라도 자신의 산의 옥돌을 가는 데에 쓸 수 있다는 뜻으로, 본이 되지 않은 남의 말이나 행동도 자신의 지식과 인격을 수양하는 데에 도움이 될 수 있음을 비유적으로 이르는 말. ≪시경≫ 에 나오는 말이다. ',
#  ' =부석05.',
#  '물건값, 요금, 임금 따위가 오른 비율. ',
#  '‘접의자’의 옛말. ',
#  '처형하는 장소. ',
#  '현재 살고 있는 곳.',
#  '【…이】닥쳐올 일에 대하여 염려가 되어 마음이 초조하고 불안하다.',
#  '풀뿌리 따위를 섞어 뭉친 흙덩이. ',
#  '일이 있는 바로 그때마다.',
#  '¶ 회의록에 지금 의결된 사항을 재기하도록 합시다.',
#  '싸움에 져서 달아나는 병정. ',
#  ' =생감자. ',
#  '누런색을 띠면서 컴컴하다. ',
#  '연달아 높게 뻗어 나간 산봉우리.',
#  '어떤 일을 대가 없이 자발적으로 참여하여 돕는 사람.',
#  '어떤 것을 기억하지 못하거나 주의를 기울이지 못하다. ‘깜박하다[3] ’보다 센 느낌을 준다. ',
#  '【…이】【-기가】낯을 들고 대하기가 부끄럽다. ≒면괴하다(面愧―). ',
#  '목의 뼈대. ',
#  '한 묶음. 또는 한 다발. ',
#  '양이 많아지거나 규모가 커지다.',
#  '충성스럽고 참된 정. ',
#  '동쪽 하늘. ',
#  '막거나 금하지 않고 터놓는 방식. ',
#  '층보 또는 지붕보를 가로로 받치는 보. ',
#  '경계하여 조심하는 마음.',
#  '예전에, 양반 가운데서도 으뜸가는 양반의 집안을 이르던 말.',
#  '녹두의 하나. ',
#  '수다를 부리다. ',
#  '바래지 않은 무명이나 광목 따위.',
#  '여러 사람이 야바위 치는 판국. ',
#  '골막바지의 구석진 곳. ',
#  '일의 뒤끝을 단단히 준비하거나 대책을 세움.',
#  '몹시 장난하다. ',
#  '장래성이 있는, 재주가 뛰어난 젊은 남자. ',
#  '「2」ㆍ톱기사(top記事). ',
#  '들어서 손해를 보다.',
#  '삼신이 할머니 모습을 하고 있다는 데서, ‘삼신04’을 달리 이르는 말. ',
#  '¶ 성크름한 날씨.',
#  '사람이 살고 있거나 살았던 지역.',
#  '꽃겟과의 하나. 몸은 검은 자주색에 푸른 무늬가 있으며 등딱지는 마름모꼴이다. 집게발이 크고 길며 나머지 발은 모두 넓적하다. 6~7월에 산란하며 식용한다. 얕은 바다의 모래땅에 떼 지어 사는데 낮에는 숨어 있다가 밤에 활동한다. 한국ㆍ일본ㆍ중국 등지에 분포한다. ≒유모05ㆍ화해05(花蟹). (Portunus trituberculatus) ',
#  '스스로 노력하지 않고 남에게 덧붙어서 살아가는 사람을 낮잡아 이르는 말. ',
#  '복제, 각색, 모조품 따위에 대하여, 그것들을 낳게 한 최초의 작품. ‘독창적’, ‘본-07’, ‘원본02’으로 순화. ',
#  '기둥을 세우고 그 위에 나무를 걸쳐 등나무 덩굴을 올리게 된 것. ',
#  '분량이 똑같이 나뉘다.',
#  '¶ 부랑자들 중에는 병원에 매혈해서 끼니를 해결하는 이들도 꽤 많다.',
#  '더할 수 없이 좋음을 비유적으로 이르는 말.',
#  '쓸데없거나 미덥지 아니한 말이나 행동을 하다. ',
#  '예전에, 병사들이 나뭇가지를 무기 삼아 서로 겨루던 놀이.',
#  '범죄 수사를 하는 능력이나 역량. ',
#  '목숨을 바치다. ',
#  '잘못이나 실수가 없도록 말이나 행동에 마음을 쓰는 성질이나 태도. ',
#  '【…을】 상대편을 누르고 첫째 자리를 차지하다.',
#  '‘비추다[2]「2」’의 피동사.',
#  '염치와 담(을) 쌓은 놈',
#  '입을 예쁘게 살짝 벌리고 소리 없이 밝고 보드랍게 자꾸 웃다. ‘방실거리다’보다 센 느낌을 준다. ≒빵실대다.',
#  '보기에 행동이 가볍고 방정맞다. ',
#  '어떤 일이나 예술 작품 따위가 질적으로 완성된 정도. ',
#  '【…을】 물을 인공적으로 모으다.',
#  '【…을】 ‘걷다02「1」’의 사동사. ',
#  '어린아이가 듣기 싫게 자꾸 울다. ≒빼빼대다.',
#  '특정 사람에게 죄를 뒤집어씌우는 것을 비유적으로 이르는 말. ≒마녀재판.',
#  '육지에서 사는 사람.',
#  '둘 또는 그 이상의 여럿 사이에 두루 통하는 점.',
#  '‘해’의 뜻을 더하는 접미사.',
#  '엷게 볼그스름하다.',
#  '남이 알아듣지 못하도록 낮은 목소리로 자질구레하게 자꾸 이야기하다. ‘숙설거리다’보다 센 느낌을 준다. ≒쑥설대다.',
#  '가난하여 살기가 어려운 나라.',
#  '지도의 뼈대를 만드는 삼각 측량(三角測量)에 필요한 원점. 우리나라에서는 수원시 영통구 원천동에 있다. ≒경위도 원점.',
#  '‘떠다박지르다’의 피동사. ',
#  '그것이 바탕이 되어 새로운 것이 생겨나는. 또는 그런 것.',
#  '수지(樹脂) 같은 고형(固形) 물질의 하나. ',
#  '잔꾀와 솜씨가 매우 교묘하다. ',
#  '멋진 데가 있다. ',
#  '물건을 팔아서 돈으로 바꿀 수 있는 성질. ',
#  '선거에 뽑힌 사람이 뽑아 준 데 대하여 고마움을 나타내는 일.',
#  '솟과의 야생 양. 몸의 길이는 1.5미터 정도이며 갈색이다. 뿔이 크고 목, 가슴, 앞발에 긴 털이 나 있다. 낮에는 바위 그늘 같은 데에서 쉬고 밤에 활동한다. 초식성으로 건조한 기후에 강한데, 임신 기간은 160일이다. 북아프리카에 분포한다. (Ammotragus lervia)',
#  '북쪽에서 불어오는 바람. ≒광막풍ㆍ광한풍ㆍ뒤바람ㆍ뒤울이ㆍ북새풍.',
#  '【…을】자기의 주장을 굽혀 남의 의견을 좇다.',
#  '국화과의 한해살이풀. 높이는 1~2미터이며, 잎은 마주나고 깃 모양으로 갈라진다. 6~10월에 흰색ㆍ분홍색ㆍ자주색 따위의 꽃이 가지 끝에 한 개씩 피고, 열매는 수과(瘦果)로 10~11월에 익는다. 관상용이고 멕시코가 원산지로 우리나라 전역에 분포한다. (Cosmos bipinnatus)',
#  '규모가 작고 시야가 좁으며 안목이 짧은 일. ',
#  '‘-냐고 해요’가 줄어든 말.',
#  '갯지렁이의 하나. 몸 뒷부분의 각 돌기 줄에는 열두 개 이상의 돌기가 있다. 등 쪽 촉각의 높이는 너비보다 짧으며 각 마디의 등 쪽에 있는 검은 무늬들은 오른쪽과 왼쪽 촉각을 잇는 줄을 이룬다.',
#  ' 공원 생활을 하다.',
#  '싸우고자 하는 굳센 마음.',
#  '「2」ㆍ지급전. ',
#  '날수대로 하는 계산.',
#  '『역사』=공작우.',
#  '망둑엇과의 바닷물고기. 몸의 길이는 10cm 정도이고 뒤로 갈수록 옆으로 납작하며, 옅은 갈색이다. 머리가 약간 납작하고 몸 옆과 등 및 꼬리지느러미 위쪽에 검은색의 무늬가 있다. 좌우 배지느러미는 합쳐져 빨판을 이룬다. 한국, 필리핀 등지에 분포한다. (Fabonigobius gymnauchen)',
#  '¶ 옷이 비에 젖어 꿉꿉하다./금세 땀이 배어난 손바닥이 꿉꿉해 왔다.≪김원일, 노을≫',
#  '길마의 앞부분이 되는 편자 모양의 나무. ',
#  '다른 나라의 물품을 사들여 오는 장사. 또는 그런 상인. ‘구매상’, ‘구매자’, ‘수입상’으로 순화. ',
#  '볕이 환하게 밝다. ',
#  '벽을 뚫어 작은 문을 내고 그 안에 물건을 넣어 두게 만든 장(欌). ≒벽다락. ',
#  '세상의 먼지라는 뜻으로, 세상의 잡다한 일을 이르는 말.',
#  '빈민이나 이재민을 구제하다.',
#  '일정한 곳에 머물러서 자고 가다. ',
#  ' =늑장01. ',
#  '인정이 두텁고 아름다운 풍속이나 습관. ',
#  '지저분하고 졸렬하다. ',
#  ' =대보름날. ',
#  '교섭이나 회의 따위에서 의견이 합쳐지지 않아 각각 갈라서게 되다.',
#  '아직까지 없던 기술이나 물건을 새로 생각하여 만들어 낸 사람. ≒발명인.',
#  '남의 사정은 돌보지 아니하고 자기가 하고 싶은 일에만 서두르는 데가 있다.',
#  '생물의 표본을 보호하거나 진열하여 놓는 방. ',
#  '『북한어』예정된 기일이 매우 걱정스럽게 다가오는 모양. ',
#  '괴상하고 기이하여 느낌이 좋지 아니하다. ',
#  '【…을】 고개를 옆으로 배틀면서 마음에 맞지 아니하거나 싫다는 뜻을 보이다.',
#  '당장 눈앞에 드러나는 이익. ',
#  '가볍고 편하거나 손쉽고 편리하다.',
#  '좋은 일에 힘이 쓰이도록 북돋아지다.',
#  '【…에/에게】【…을】지위가 높거나 존경하는 사람을 찾아가 뵈다. ≒면알하다ㆍ배오하다ㆍ예알하다.',
#  '쓸쓸히 비치는 등불. ',
#  '해당 설비를 갖추고 검사하고 측정하는 일을 맡아보는 곳이나 부서. 또는 그 건물. ',
#  '사회 운동, 정치 운동, 저항 운동 따위를 비합법적으로 숨어서 하는 영역.',
#  '‘기다01[1]’의 옛말. ',
#  '담을 것은 많은데 광주리가 작다',
#  '‘전자 궤도’의 북한어.',
#  '당번을 설 차례가 아님. ',
#  '이미 정해진 형벌에 정도를 더하다.',
#  '【…을】 전임자가 후임자에게 맡아보던 일이나 물건을 넘겨서 맡기다.',
#  '절개가 굳은 남자.',
#  '【…을】 전례나 명령을 좇아서 받들다. ≒순봉하다.',
#  '여럿이 어떤 범위 안을 향하여 오다. ≒괴어들다. ',
#  '‘닭’의 옛말. ',
#  '¶ 승강기 문이 털거덩하며 닫힌다.∥경리가 금고 문을 털거덩하고 닫았다.',
#  '장례에서, 나장(裸葬)을 하려고 하관할 때에 시신을 꺼내고 관을 벗겨 치우다.',
#  '잘라지거나 베어져서 끊어지다. ≒단절되다01.',
#  '공명통이 달린 보통 기타를 일상적으로 이르는 말. ',
#  '건축이나 토목 따위에 쓰는, 돌로 된 재료. ≒돌02.',
#  '‘복인03(服人)’을 낮잡아 이르는 말.',
#  '【…을】 한쪽 다리가 짧거나 탈이 나서 자꾸 뒤뚝뒤뚝 절다. ≒절뚝대다.',
#  '상품의 값을 써 붙인 표. ',
#  '【…을】 영양분이 많은 음식이나 약을 먹어 몸의 건강을 돕다. ',
#  '【…을】 쳐들어 높이다.',
#  '범의귓과의 여러해살이풀. 줄기는 높이가 1미터 정도이고 굵고 꼿꼿하며, 잎은 어긋나고 손바닥 모양으로 갈라진다. 6월에 황백색의 잔꽃이 원추(圓錐) 화서로 피고 열매는 삭과(蒴果)이다. 깊은 산에 나는데 강원, 경북, 평북, 함남, 함북 등지에 분포한다. (Rodgersia podophylla) ',
#  '【…을】 잘못하여 디딜 자리가 아닌 다른 자리를 디디다. ',
#  '남의 인격이나 권리 따위를 침해하다. ',
#  ...]

# %%
import re
re.findall(r"[^ 가-힣]+", mdkDict[:3][0][0])
# Out:
# ['ᄛ']

# %%
result[:4]
# Out:
# [['ᄛ',
#   'ᄛ',
#   '『옛말』',
#   '『언어』',
#   '한글 옛 자모의 하나. 반설경음이라 이르며, 혀끝이 윗잇몸을 가볍게 두들겨 내는 유음으로 짐작된다.\r\n'],
#  ['ᄻ',
#   'ᄻ',
#   '『옛말』',
#   '한글 옛 자모 ‘ㅎ’의 된소리를 적는 자모. ‘\uec96다’의 ‘\uec96’에서와 같이 초성으로만 쓰였다.\r\n'],
#  ['ᆐ', 'ᆐ', '「명사」', '『옛말』', '『언어』', '훈민정음 모음 글자의 하나, ‘\uf31d’의 중성으로 썼다.\r\n'],
#  ['ㄱ',
#   'ㄱ01 [기역]',
#   ':〔ㄱ만[기영-]〕',
#   '「명사」',
#   '『언어』',
#   '한글 자모의 첫째 글자. 기역이라 이르며, ‘가’에서와 같이 초성으로, ‘역’에서와 같이 종성으로 쓰인다. 목젖으로 콧길을 막고 혀뿌리를 높여 연구개를 막았다가 뗄 때 나는 무성음이다. 초성일 때는 무성이나 모음 사이에서는 유성음이 되며, 종성일 때는 혀뿌리를 떼지 않고 발음한다. 혀뿌리가 목구멍을 막는 모양을 본떠서 만든 글자이다.\r\n']]

# %%
# %whos
# Out:
# Variable     Type          Data/Info
# ------------------------------------
# conn         Connection    <sqlite3.Connection object at 0x7f2f291d6490>
# df           DataFrame            entry             <...>[516490 rows x 2 columns]
# exportTxt    function      <function exportTxt at 0x7f2f5472d9d8>
# fromstring   function      <function fromstring at 0x7f2f274d7c80>
# itemData     list          n=516490
# itemIndex    list          n=516490
# pd           module        <module 'pandas' from '/h<...>ages/pandas/__init__.py'>
# resp         Cursor        <sqlite3.Cursor object at 0x7f2f29176dc0>
# result       list          n=200000
# sqlite3      module        <module 'sqlite3' from '/<...>3.6/sqlite3/__init__.py'>
# tableNames   list          n=2

# %%
# http://schoolofweb.net/blog/posts/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%A0%9C%EB%84%88%EB%A0%88%EC%9D%B4%ED%84%B0-generator/

# %%
def square_numbers(nums):
    for i in nums:
        yield i * i

my_nums = square_numbers([1, 2, 3, 4, 5])  #1
next(my_nums)
# Out:
# 1

# %%
def foo(a, b):
    if a < 3:
        yield a, b
        a += 1
        for a, v in foo(a, b):
            yield a, v
    else:
        yield a, b

for a, v in foo(1, 2):
    print(a, v)
# Out:
# 1 2
# 2 2
# 3 2

# %%
itemData

# %%
import re # 강결합으로 정치큰 부분 제거하기
re.sub('<br><font .*</font><br>', "",data)
# Out:
# '<font color=crimson size=+2><b>ᄛ</b></font><br><br><font color="#00008b"><b>ᄛ</b></font>『옛말』<br>『언어』<br>한글 옛 자모의 하나. 반설경음이라 이르며, 혀끝이 윗잇몸을 가볍게 두들겨 내는 유음으로 짐작된다.\r\n'

# %%
_ = re.sub('<font .*</font><br>', "",data).split("<br>")
_[0], _[1].replace("\r\n", "")
# Out:
# ('', '<font color="#00008b"><b>ᄛ</b></font>『옛말』')

# %%
import re
from lxml.html import fromstring
def exportMdx(data):
    data = data.lower()  # html Tag 전처리
    _ = re.sub('<font .*</font><br>', "",data).split("<br>")
    return fromstring(data).xpath('//font//text()'), (_[0], _[1].replace("\r\n", ""))

# %%
result = []
from tqdm import tqdm
for _ in tqdm(itemData):
    result.append(exportMdx(_))
# Out:
#   0%|          | 0/516490 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-5fefc626479d> in <module>
#       2 from tqdm import tqdm
#       3 for _ in tqdm(itemData):
# ----> 4     result.append(exportMdx(_))
#
# <ipython-input-4-e0dab9d9f118> in exportMdx(data)
#       4     data = data.lower()  # html Tag 전처리
#       5     _ = re.sub('<font .*</font><br>', "",data).split("<br>")
# ----> 6     return fromstring(data).xpath('//font//text()'), (_[0], _[1].replace("\r\n", ""))
#
# IndexError: list index out of range

# %%
def exportTag(data):
    temp = data.lower()
    temp = fromstring(temp).xpath('//font[@color="#549606"]//text()')
    return temp.strip()

from lxml.html import fromstring
from tqdm import tqdm
result = []
for _ in tqdm(itemData):
    result.append(exportTag(_))
tags = list(set(result))
# Out:
#   0%|          | 0/516490 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-59a8cf855427> in <module>
#       8 result = []
#       9 for _ in tqdm(itemData):
# ---> 10     result.append(exportTag(_))
#      11 tags = list(set(result))
#
# <ipython-input-21-59a8cf855427> in exportTag(data)
#       2     temp = data.lower()
#       3     temp = fromstring(temp).xpath('//font[@color="#549606"]//text()')
# ----> 4     return temp.strip()
#       5
#       6 from lxml.html import fromstring
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
tags
# Out:
# ['「조사」']

# %%
temp = str(df.entry[0])

# %%
temp
# Out:
# 'ᄛ'
